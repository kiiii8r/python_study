# %%
import ffmpeg

# %%
stream = ffmpeg.input("2023-06-08 12-11-54のコピー.mp4")

# %%
stream = ffmpeg.output(stream, "aws.wav")

# %%
ffmpeg.run(stream)
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '2023-06-08 12-11-54のコピー.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:25:00.73, start: 0.000000, bitrate: 486 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 281 kb/s, 60 fps, 60 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 191 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'aws.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf60.3.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 pcm_s16le
# size=  281384kB time=00:25:00.69 bitrate=1536.0kbits/s speed= 499x
# video:0kB audio:281384kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000027%
# (None, None)

# %%
# !pip install git+https://github.com/openai/whisper
# Out:
# Collecting git+https://github.com/openai/whisper
#   Cloning https://github.com/openai/whisper to /private/var/folders/22/ll639cxd4g55wcvnnc2pfklw0000gn/T/pip-req-build-f61l1mgg
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper /private/var/folders/22/ll639cxd4g55wcvnnc2pfklw0000gn/T/pip-req-build-f61l1mgg
#   Resolved https://github.com/openai/whisper to commit 248b6cb124225dd263bb9bd32d060b6517e067f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from openai-whisper==20230314) (1.22.4)
# Requirement already satisfied: tqdm in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from openai-whisper==20230314) (4.64.0)
# Collecting torch
#   Downloading torch-2.0.1-cp39-none-macosx_10_9_x86_64.whl (143.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 MB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting numba
#   Downloading numba-0.57.0-cp39-cp39-macosx_10_9_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 7.9 MB/s eta 0:00:0000:0100:01
# Collecting more-itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 1.7 MB/s eta 0:00:00
# Collecting tiktoken==0.3.3
#   Downloading tiktoken-0.3.3-cp39-cp39-macosx_10_9_x86_64.whl (736 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.3/736.3 kB 6.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: regex>=2022.1.18 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from tiktoken==0.3.3->openai-whisper==20230314) (2022.8.17)
# Requirement already satisfied: requests>=2.26.0 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from tiktoken==0.3.3->openai-whisper==20230314) (2.27.1)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1rc1-cp39-cp39-macosx_10_9_x86_64.whl (30.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 7.1 MB/s eta 0:00:0000:0100:01
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 8.1 MB/s eta 0:00:0000:0100:01
# Collecting filelock
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: jinja2 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from torch->openai-whisper==20230314) (3.1.2)
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from torch->openai-whisper==20230314) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages (from jinja2->torch->openai-whisper==20230314) (2.1.1)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 6.4 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798063 sha256=e60bcc4ac5ff50dcdd1f4953948f1da84965368dc7c6ec118f4fef1f8113bd0c
#   Stored in directory: /private/var/folders/22/ll639cxd4g55wcvnnc2pfklw0000gn/T/pip-ephem-wheel-cache-jggv3fe5/wheels/51/39/66/468e1ba10eb12b1365f557d42973b913c612807575dbdb9574
# Successfully built openai-whisper
# Installing collected packages: mpmath, sympy, networkx, more-itertools, llvmlite, filelock, torch, tiktoken, numba, openai-whisper
# Successfully installed filelock-3.12.2 llvmlite-0.40.1rc1 more-itertools-9.1.0 mpmath-1.3.0 networkx-3.1 numba-0.57.0 openai-whisper-20230314 sympy-1.12 tiktoken-0.3.3 torch-2.0.1
#
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import whisper

# %%
whisper.available_models()
# Out:
# ['tiny.en',
#  'tiny',
#  'base.en',
#  'base',
#  'small.en',
#  'small',
#  'medium.en',
#  'medium',
#  'large-v1',
#  'large-v2',
#  'large']

# %%
input_voice = "aws.wav"
model = whisper.load_model("small")

# %%
result = model.transcribe(input_voice)
# Out:
# /Users/kii/opt/anaconda3/envs/pyenv/lib/python3.9/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
recognized_text = result['text']
print(recognized_text)
# Out:
# なんかウエアラブルデバイス 時計とかあとは家庭の中で電気をつけたりとか車が自動運転とかなんかその辺がイメージに浮かんできますそうですね まさに私の家が声でだけで全部の証明と管理してるだって話しましたけどまさにそれも一つですねこのようにものがインターネットにつながる世界その技術をまとめて IoTと呼びます皆さんの結構身近にもあるんじゃないかなと思うんですね今の家電とかもそうです 下等圏もちろんそうですしあとは車もインターネットに今はつながっていたりするそれを制御する また活用することによってより効率的に皆さんの豊かな生活に紐付いているなんていう技術だったりしますさあこの IoT 皆さんに短いと言ったんですが実はちょっと難しいところもあるんですね例えばものがあります 物理的なものがあるこのものをやっぱ管理をしなきゃいけないわけですこのものの管理というのは物理的なものになってくるので一元的に管理をするために仕組みとかがないとなかなか難しい扱いにくい部分とかあとはもちろんネットワークと組み合わせて使っていくので そこの設定の部分であったりとかものがたくさんあればあるほどその管理も大変ですよねそこでAWSではこのものの管理も効率的に行えるようなそんなサービスラインナップというのがありまして AWS IoTサービス群ちょっとここで一部ご紹介していきますいくつかジャンルがありましてまず右下を見てくださいデバイスソフトウェアと書いてあるんですがこれがそのものを管理するときに使うものに入れて使うサービスであっているとか機能ですそしてそのデバイス例えばセンサーデバイスでもいいですし一部とっけでもいいんですけれどもそれとクラウドをつなぐ部分というのが左下の接続と制御というところですたくさんつながったデバイスを一元的に扱ったりするなんていうところもここで行っていきますそしてですね 平原さんものとつながっていくとデータをたくさん取得したりとか例えばセンサーデバイスでそうですよねいるのデータが入ってくると思いますそれをまとめて新しい知見を得るなんていう使い方ができるんです分析に使うということですまさにそれがこちら分析サービスこれも対応している特化型のサービスっていろいろありましてここで細かいところというよりはいろいろな使い方があるんだなそれを組み合わせられるんだなと思っていただければと思いますそしてその使われているところなんですけれどもさっきもいくつか例をご紹介しました今お話したところでと右上ですかね家庭の中で使われているっていう話であったりとか下真ん中右のコネクテットとかももちろんそうですし昨日も工場の中でさまざまな機器にデバイスをつけて振動を監視させて障害を見つけるとかですねあとはリモートの看護いろいろの分野です遠くにいる患者さんの状況をリモートを使ってもののデバイスをつけてあげてここで心拍を測ったり熱を測ったりその情報が飛んでくるってことですそういうことですそれを使ってクラウドで注約をして一元的に管理をする何ていう使い方もあったりとかあと左下ですねこれは農業の部分だったりとかいろいろなところでものが使われるようなってきているそれがこのIoTの世界ですそしてこのIoTはIoTだけではなくいろいろな今日もご紹介してきたようなサービスと組み合わせてやりたいことの実験というのができますだから物からデータを持ってきてそれをきっかけに何かしらの処理を行うデータを保存する畑も畑他のサービスに連携をする平和さんの好きな分析を行うもちろんできますここでいくつかアイコン並べていますけれどもこれを組み合わせることによってやりたいことを高速に実験できるこれがAWSでありその一つがIoTコアと今のIoTのサービスになってきますなるほどそしてここで一個例をご紹介しようかなと思うんですけど事例があるんですねそうですそれがこちらバイルクロップサイエンスという会社さまの事例をご紹介しますこちらはいわゆる農業アグリティックと呼ばれているものなんですが趣旨ですね種の事業を行われているお客さまですその種を育てていくという時になった時にはやはり土壌の状況であったりとかあとは気温とか出動とかそういった機構的な情報も踏まえて管理をしていかないと生育というのは難しいですよね今まではそれを人間の目で確認するとかそれを一個まとめて後で分析を行うとかってやられたらそうなんですけどもそれを今のIoTを使うことによって一元的に同時に情報を取得をしてすぐに分析ができるようになったのでよりスピーディに判断が行えるようになったよりサーバー化しやすくなるそういったことを実験されていたりします農業分野でもこんな活躍の仕方をしているんですねはい色んなところで今使われているIoTの一つの例をご紹介しましたはいありがとうございますそして次ですね平坊さんもしかしてこんな勉強してるんじゃないですかね機械学習機械学習最近流行りですよね私も一生懸命本を読んだりしてますやっぱり皆さんもしかしたら聞かれているよ勉強されているよという方も多いかもしれませんかなり短いなってきたこのキーワードなんですけどもAWSでももちろんできますただちょっと一つだけ先に用語の整理だけしようと思いますはい平坊さん機械学習というとよくなんかAIとかはいよく出てくるキーワードですAIとかディープラーニングとかですかね聞きますよねはいきますよね実はあれは方眼関係にあるちょっと位置関係があるんですねそこだけ先に整理しますまずAI人工知能というのは機械学習関連の総称になっていてさまざまな機能であったりとかできることとかをまとめて人工知能と呼んだりしますその中で機械学習を行って何か特徴点を見つけるなんていうことそれを行えることを機械学習というのですねこれもよく聞くキーワードだと思いますはいよくもねそしてその中で使うテクノロジーとして新総学習先ほど出ましたねこれはより効率的にスピーディに詳しい分析が行えるようにするそんなモデルが作れるようなちょっと新しい技術なんですけれどもこれが新総学習その中の一つの手段と思っていただければと思いますなるほどこういう関連性があるんですねはいここからお話ししようと思うのはその真ん中に書いてある機械学習というマシンを使ったり何かしたらモデルを作るなんていうところができる相談お話をしていきますはいがその前にAWSの切る機械学習は実はAmazonここがベースになってますはいAmazonで買い物ってしたことありますありますあの時って例えば買い物をするというのとひらがさんこれ買いませんかというおすすめとかではないですか結構来ますねおすすめ商品一覧みたいなのが出てきていますねおそらく私とひらがさん全然違うものが出てくると思うんですそれというのは皆さんのここに売り出来とか他の方々の売り出来とかを踏まえながらこういうものを買うんじゃないかというおすすめエンジンというのが裏側で動いているんですねこれもまさに機械学習の一つあとはお急ぎ瓶とかってあるじゃないですかありますねあれとかは早くとても嬉しいですよねはいというを実現するために倉庫の自動化というのが行われていて実際はロボットとかが動いているんです商品をですね持ってきてきているロボットが自動で動いてくれることによってより効率的に商品をピックアップをしたり箱詰めを行った後に発送を行うなんていうことも実現していたりあとは今日中から出ましたねスマートスピーカーAmazonエコーもまさにAIサービスアレクサですねアレクサそして最近はですねドローも使った配達の自動化なんていうのを入っていたりとか皆さんの生活が豊かになるようなそんな新しいイノベーションというものを機械学習をベースに実現していたりしますでここまでAmazonの話をしたんですがそれなぜかと言いますとこの土甲ったテクノロジーを皆様が使えるようにするそれがAWSの開ける機械学習です実は色々ありましてちょっと一覧だとこんな感じですねすごい数があるんですねちょっと整理しますね上からAIサービス真ん中が機械学習サービスそして一番下がMLフレームアク機械学習フレームアクという大きく3つに分かりますまずですね真ん中をご紹介しましょう真ん中から下を2つ共通しているのがご自身でモデルを作りたいんだというセルフサービスで機械学習をやりたいよという皆さん向けのサービスです特にその中でもお引き合いが多いのはこの真ん中の機械学習サービスこれは政治メーカーというサービスで実現できますこれもいろいろなことができるんですけども基本的に機械学習って簡単に言うとデータを用意してそのデータを機械に読み込ませて何かしらの特徴点を見つけてちょっとチューニングという改善を行ってあとはそれを使って予測を行う一般的にはこうやって流れていきますその流れの中って結構いろいろ大変なことがあるんですけど平川さんはこれ勉強している中で大変そうだなと思ったことありますかそもそも基盤付くの大変ですよねこのトレーニングをさせるために準備をする部分機械の部分ですねそうなんですよたくさん必要ですしねそれから当然データもたくさん集めないといけないので大変ですがあとトレーニングをさせながらチューニングっていうところが結構大変そうな気がしましたそうですね実際一回だけではなくてそれを改善していくっていう作業を通してより精度を上げているこれ一般的な話なんですがこれ全部大変ですよね実際一般的に機械学習というのは8割がその準備に数がかかる時間がかかると言われていますでもやりたいのってその先ですよね最終的な予測を作るところですよね予測を作ってそれを見たいわけ ...
