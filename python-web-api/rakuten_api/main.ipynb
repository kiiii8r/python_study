# %% [markdown]
# 楽天API（商品検索）：
# https://webservice.rakuten.co.jp/documentation/ichiba-product-search
# APIキー：
# 1036322915713144338

# %%
import requests
import pandas as pd

# %%
REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Product/Search/20170426'
APP_ID = '1036322915713144338'

# %%
params = {
    'applicationId': APP_ID,
    'format': 'json',
    'keyword': 'バスローブ',
    'minPrice': 10000
}

# %%
res = requests.get(REQUEST_URL, params)

# %%
res.status_code
# Out:
# 200

# %%
result = res.json()
res.json()
# Out:
# {'GenreInformation': {'children': [], 'current': [], 'parent': []},
#  'Products': [{'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 15840,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 2,
#    'makerCode': '104547561',
#    'makerName': '丸栄タオル',
#    'makerNameFormal': '丸栄タオル株式会社',
#    'makerNameKana': 'マルエイタオル',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/104547561/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/104547561/',
#    'maxPrice': 15840,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/547/561/020/079/10010004547561020079_1.jpg?_ex=128x128',
#    'minPrice': 15840,
#    'productCaption': '',
#    'productId': 'b35e7bfa7ab8a069f7ff96a6a52883d9',
#    'productName': 'いまばりタオル\u3000吸水クロスバスローブ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/b35e7bfa7ab8a069f7ff96a6a52883d9/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/b35e7bfa7ab8a069f7ff96a6a52883d9/',
#    'rank': 5522,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 4.67,
#    'reviewCount': 24,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/b35e7bfa7ab8a069f7ff96a6a52883d9/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/b35e7bfa7ab8a069f7ff96a6a52883d9/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 15840,
#    'salesMinPrice': 15840,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/547/561/020/079/10010004547561020079_1.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 15840,
#    'usedExcludeMinPrice': 15840,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 15840,
#    'usedExcludeSalesMinPrice': 15840},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 15840,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 2,
#    'makerCode': '104547561',
#    'makerName': '丸栄タオル',
#    'makerNameFormal': '丸栄タオル株式会社',
#    'makerNameKana': 'マルエイタオル',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/104547561/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/104547561/',
#    'maxPrice': 15840,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 15840,
#    'productCaption': '',
#    'productId': 'f7829782da452b876ea242e2f9ad146f',
#    'productName': 'モコモコ肌触りで癒しのバスローブ アイボリー',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/f7829782da452b876ea242e2f9ad146f/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/f7829782da452b876ea242e2f9ad146f/',
#    'rank': 5519,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 4.4,
#    'reviewCount': 10,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/f7829782da452b876ea242e2f9ad146f/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/f7829782da452b876ea242e2f9ad146f/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 15840,
#    'salesMinPrice': 15840,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 15840,
#    'usedExcludeMinPrice': 15840,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 15840,
#    'usedExcludeSalesMinPrice': 15840},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 19800,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 3,
#    'makerCode': '104547561',
#    'makerName': '丸栄タオル',
#    'makerNameFormal': '丸栄タオル株式会社',
#    'makerNameKana': 'マルエイタオル',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/104547561/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/104547561/',
#    'maxPrice': 19800,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 19800,
#    'productCaption': '',
#    'productId': 'a24f8e90091a4e7ca0bc7b91ca651108',
#    'productName': 'オーガニック使用の最高級ワッフル織りキモノローブ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/a24f8e90091a4e7ca0bc7b91ca651108/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/a24f8e90091a4e7ca0bc7b91ca651108/',
#    'rank': 39,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/a24f8e90091a4e7ca0bc7b91ca651108/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/a24f8e90091a4e7ca0bc7b91ca651108/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 19800,
#    'salesMinPrice': 19800,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 3,
#    'usedExcludeMaxPrice': 19800,
#    'usedExcludeMinPrice': 19800,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 19800,
#    'usedExcludeSalesMinPrice': 19800},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 14300,
#    'brandName': 'デアアフェット',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 2,
#    'makerCode': '10458007505',
#    'makerName': 'アフェット',
#    'makerNameFormal': '株式会社アフェット',
#    'makerNameKana': 'アフエツト',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/10458007505/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/10458007505/',
#    'maxPrice': 14300,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/580/075/050/187/10010004580075050187_1.jpg?_ex=128x128',
#    'minPrice': 14300,
#    'productCaption': '',
#    'productId': '2cc3333526abf3442f4b9719a8e95710',
#    'productName': 'デアアフェットスリムバスローブ(ロング丈)ベージュ',
#    'productNo': 'AFBT13-0012',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/2cc3333526abf3442f4b9719a8e95710/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/2cc3333526abf3442f4b9719a8e95710/',
#    'rank': 5860,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 3.5,
#    'reviewCount': 2,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/2cc3333526abf3442f4b9719a8e95710/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/2cc3333526abf3442f4b9719a8e95710/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 14300,
#    'salesMinPrice': 14300,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/580/075/050/187/10010004580075050187_1.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 14300,
#    'usedExcludeMinPrice': 14300,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 14300,
#    'usedExcludeSalesMinPrice': 14300},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 16133,
#    'brandName': 'パシーマ',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 7,
#    'makerCode': '104903357',
#    'makerName': '龍宮',
#    'makerNameFormal': '龍宮株式会社',
#    'makerNameKana': 'リユウグウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/104903357/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/104903357/',
#    'maxPrice': 20533,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/903/357/254/026/10010004903357254026_1.jpg?_ex=128x128',
#    'minPrice': 15400,
#    'productCaption': '',
#    'productId': '10aab8959fdbbac70f50c23c87f03829',
#    'productName': 'パシーマ リラックスローブ きなり(1枚入)',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/10aab8959fdbbac70f50c23c87f03829/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/10aab8959fdbbac70f50c23c87f03829/',
#    'rank': 2516,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '2014年10月1日',
#    'reviewAverage': 4.45,
#    'reviewCount': 20,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/10aab8959fdbbac70f50c23c87f03829/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/10aab8959fdbbac70f50c23c87f03829/review/',
#    'salesItemCount': 6,
#    'salesMaxPrice': 15400,
#    'salesMinPrice': 15400,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/903/357/254/026/10010004903357254026_1.jpg?_ex=64x64',
#    'usedExcludeCount': 7,
#    'usedExcludeMaxPrice': 20533,
#    'usedExcludeMinPrice': 15400,
#    'usedExcludeSalesItemCount': 6,
#    'usedExcludeSalesMaxPrice': 15400,
#    'usedExcludeSalesMinPrice': 15400},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 15840,
#    'brandName': '',
#    'genreId': '510859',
#    'genreName': 'パジャマ',
#    'itemCount': 3,
#    'makerCode': '104547561',
#    'makerName': '丸栄タオル',
#    'makerNameFormal': '丸栄タオル株式会社',
#    'makerNameKana': 'マルエイタオル',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510859/104547561/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510859/104547561/',
#    'maxPrice': 15840,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 15840,
#    'productCaption': '',
#    'productId': 'e430fe5e9212525a02dd3962a162e97c',
#    'productName': 'オーガニック使用の最高級ワッフル織りパジャマワンピース Ｍ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/e430fe5e9212525a02dd3962a162e97c/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/e430fe5e9212525a02dd3962a162e97c/',
#    'rank': 5527,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 4.25,
#    'reviewCount': 4,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/e430fe5e9212525a02dd3962a162e97c/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/e430fe5e9212525a02dd3962a162e97c/review/',
#    'salesItemCount': 3,
#    'salesMaxPrice': 15840,
#    'salesMinPrice': 15840,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 3,
#    'usedExcludeMaxPrice': 15840,
#    'usedExcludeMinPrice': 15840,
#    'usedExcludeSalesItemCount': 3,
#    'usedExcludeSalesMaxPrice': 15840,
#    'usedExcludeSalesMinPrice': 15840},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 12980,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '10457133515',
#    'makerName': 'バスリエ',
#    'makerNameFormal': 'バスリエ株式会社',
#    'makerNameKana': 'バスリエ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/10457133515/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/10457133515/',
#    'maxPrice': 12980,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/335/150/006/10010004571335150006_1.jpg?_ex=128x128',
#    'minPrice': 12980,
#    'productCaption': '',
#    'productId': '8fcd3981f7790e2210310bd1926637ee',
#    'productName': 'バスローブ(スプレンディー)ヤングカットローブ（S）( ボディローブ 部屋着 bathrobe)',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/8fcd3981f7790e2210310bd1926637ee/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/8fcd3981f7790e2210310bd1926637ee/',
#    'rank': 40,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 4.27,
#    'reviewCount': 110,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/8fcd3981f7790e2210310bd1926637ee/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/8fcd3981f7790e2210310bd1926637ee/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 12980,
#    'salesMinPrice': 12980,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/335/150/006/10010004571335150006_1.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 12980,
#    'usedExcludeMinPrice': 12980,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 12980,
#    'usedExcludeSalesMinPrice': 12980},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 13750,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 2,
#    'makerCode': '10456031359',
#    'makerName': '田中産業',
#    'makerNameFormal': '田中産業株式会社',
#    'makerNameKana': 'タナカサンギヨウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/10456031359/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/10456031359/',
#    'maxPrice': 13750,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/924/10010004560313591924_1.jpg?_ex=128x128',
#    'minPrice': 13750,
#    'productCaption': '',
#    'productId': 'f2c1b1c320b1fc4ce4b0260be726dbe9',
#    'productName': '今治タオル バスローブ レディース オレンジ 約 ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/f2c1b1c320b1fc4ce4b0260be726dbe9/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/f2c1b1c320b1fc4ce4b0260be726dbe9/',
#    'rank': 5622,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 4,
#    'reviewCount': 1,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/f2c1b1c320b1fc4ce4b0260be726dbe9/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/f2c1b1c320b1fc4ce4b0260be726dbe9/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 13750,
#    'salesMinPrice': 13750,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/924/10010004560313591924_1.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 13750,
#    'usedExcludeMinPrice': 13750,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 13750,
#    'usedExcludeSalesMinPrice': 13750},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 11087,
#    'brandName': '',
#    'genreId': '112779',
#    'genreName': 'その他',
#    'itemCount': 2,
#    'makerCode': '10457134944',
#    'makerName': 'サイバール',
#    'makerNameFormal': 'サイバール株式会社',
#    'makerNameKana': 'サイバール',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/112779/10457134944/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/112779/10457134944/',
#    'maxPrice': 11467,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/349/448/564/10010004571349448564_1.jpg?_ex=128x128',
#    'minPrice': 10707,
#    'productCaption': '',
#    'productId': '838c92c6b5f112a14d062ce4dd8897f3',
#    'productName': 'ブルーム 今治産 Fit-Useフィットユース キッズ バスローブ 子供用 S ホワイト',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/838c92c6b5f112a14d062ce4dd8897f3/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/838c92c6b5f112a14d062ce4dd8897f3/',
#    'rank': 0,
#    'rankTargetGenreId': '0',
#    'rankTargetProductCount': 0,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/838c92c6b5f112a14d062ce4dd8897f3/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/838c92c6b5f112a14d062ce4dd8897f3/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 11467,
#    'salesMinPrice': 10707,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/349/448/564/10010004571349448564_1.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 11467,
#    'usedExcludeMinPrice': 10707,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 11467,
#    'usedExcludeSalesMinPrice': 10707},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 10450,
#    'brandName': '',
#    'genreId': '304015',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '0',
#    'makerName': '',
#    'makerNameFormal': '',
#    'makerNameKana': '',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/304015/0/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/304015/0/',
#    'maxPrice': 10450,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/3001/0008/033/549/715/045/30010008033549715045_1.jpg?_ex=128x128',
#    'minPrice': 10450,
#    'productCaption': '',
#    'productId': '24e7d74d6a11a13348a496bf17f6543b',
#    'productName': '（NAPKIN）BATHROBE（ナプキン\u3000バスローブ）\u3000ブラック（L・XL）\u3000bh0166',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/24e7d74d6a11a13348a496bf17f6543b/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/24e7d74d6a11a13348a496bf17f6543b/',
#    'rank': 1271,
#    'rankTargetGenreId': '304013',
#    'rankTargetProductCount': 1272,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/24e7d74d6a11a13348a496bf17f6543b/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/24e7d74d6a11a13348a496bf17f6543b/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 10450,
#    'salesMinPrice': 10450,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/3001/0008/033/549/715/045/30010008033549715045_1.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 10450,
#    'usedExcludeMinPrice': 10450,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 10450,
#    'usedExcludeSalesMinPrice': 10450},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 10511,
#    'brandName': '',
#    'genreId': '216832',
#    'genreName': 'その他',
#    'itemCount': 4,
#    'makerCode': '10456010985',
#    'makerName': 'オルネット',
#    'makerNameFormal': '株式会社オルネット',
#    'makerNameKana': 'オルネツト',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/216832/10456010985/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/216832/10456010985/',
#    'maxPrice': 11776,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/323/279/153/10010004571323279153_1.jpg?_ex=128x128',
#    'minPrice': 9337,
#    'productCaption': '',
#    'productId': 'e27608017fef385da71e77e35314d0cb',
#    'productName': 'オルネット Oh dear パイルバスローブ ブラウン OGBW102BR90',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/e27608017fef385da71e77e35314d0cb/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/e27608017fef385da71e77e35314d0cb/',
#    'rank': 20,
#    'rankTargetGenreId': '216832',
#    'rankTargetProductCount': 56,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/e27608017fef385da71e77e35314d0cb/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/e27608017fef385da71e77e35314d0cb/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 11776,
#    'salesMinPrice': 11596,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/323/279/153/10010004571323279153_1.jpg?_ex=64x64',
#    'usedExcludeCount': 4,
#    'usedExcludeMaxPrice': 11776,
#    'usedExcludeMinPrice': 9337,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 11776,
#    'usedExcludeSalesMinPrice': 11596},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 13500,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '10456031359',
#    'makerName': '田中産業',
#    'makerNameFormal': '田中産業株式会社',
#    'makerNameKana': 'タナカサンギヨウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/10456031359/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/10456031359/',
#    'maxPrice': 13500,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/382/10010004560313591382_1.jpg?_ex=128x128',
#    'minPrice': 13500,
#    'productCaption': '',
#    'productId': '867b70bf183e3b83ea3fcc754929818d',
#    'productName': '今治タオル バスローブ ナンバーカラー レディース 06 イエロー',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/867b70bf183e3b83ea3fcc754929818d/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/867b70bf183e3b83ea3fcc754929818d/',
#    'rank': 5615,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/867b70bf183e3b83ea3fcc754929818d/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/867b70bf183e3b83ea3fcc754929818d/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 13500,
#    'salesMinPrice': 13500,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/382/10010004560313591382_1.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 13500,
#    'usedExcludeMinPrice': 13500,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 13500,
#    'usedExcludeSalesMinPrice': 13500},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 25517,
#    'brandName': '',
#    'genreId': '565248',
#    'genreName': '冷蔵庫・冷凍庫用アクセサリー',
#    'itemCount': 7,
#    'makerCode': '104511895',
#    'makerName': '中忠',
#    'makerNameFormal': '中忠株式会社',
#    'makerNameKana': 'ナカチユウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/565248/104511895/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/565248/104511895/',
#    'maxPrice': 27500,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/511/895/023/990/10010004511895023990_1.jpg?_ex=128x128',
#    'minPrice': 21692,
#    'productCaption': '',
#    'productId': '32f58c39f52b429ab919f9672b0f832d',
#    'productName': '極ふわ やさしいたおる‐premium‐ バスローブ ベージュ YTP－172501',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/32f58c39f52b429ab919f9672b0f832d/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/32f58c39f52b429ab919f9672b0f832d/',
#    'rank': 1048,
#    'rankTargetGenreId': '565080',
#    'rankTargetProductCount': 5218,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/32f58c39f52b429ab919f9672b0f832d/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/32f58c39f52b429ab919f9672b0f832d/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 22817,
#    'salesMinPrice': 21692,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/511/895/023/990/10010004511895023990_1.jpg?_ex=64x64',
#    'usedExcludeCount': 7,
#    'usedExcludeMaxPrice': 27500,
#    'usedExcludeMinPrice': 21692,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 22817,
#    'usedExcludeSalesMinPrice': 21692},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 31900,
#    'brandName': '',
#    'genreId': '101877',
#    'genreName': 'その他',
#    'itemCount': 3,
#    'makerCode': '0',
#    'makerName': '',
#    'makerNameFormal': '',
#    'makerNameKana': '',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/101877/0/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/101877/0/',
#    'maxPrice': 31900,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/3001/0005/722/000/234/906/30010005722000234906_1.jpg?_ex=128x128',
#    'minPrice': 31900,
#    'productCaption': '',
#    'productId': 'cb228f95c89a7361327a8fcf8227cfb2',
#    'productName': 'ゾーン ZONE DENMARK ゾーンデンマーク 北欧デザイン バスローブ パジャマ 寝巻 Inu グレー 23490',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/cb228f95c89a7361327a8fcf8227cfb2/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/cb228f95c89a7361327a8fcf8227cfb2/',
#    'rank': 0,
#    'rankTargetGenreId': '0',
#    'rankTargetProductCount': 0,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/cb228f95c89a7361327a8fcf8227cfb2/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/cb228f95c89a7361327a8fcf8227cfb2/review/',
#    'salesItemCount': 3,
#    'salesMaxPrice': 31900,
#    'salesMinPrice': 31900,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/3001/0005/722/000/234/906/30010005722000234906_1.jpg?_ex=64x64',
#    'usedExcludeCount': 3,
#    'usedExcludeMaxPrice': 31900,
#    'usedExcludeMinPrice': 31900,
#    'usedExcludeSalesItemCount': 3,
#    'usedExcludeSalesMaxPrice': 31900,
#    'usedExcludeSalesMinPrice': 31900},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 13500,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '10456031359',
#    'makerName': '田中産業',
#    'makerNameFormal': '田中産業株式会社',
#    'makerNameKana': 'タナカサンギヨウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/10456031359/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/10456031359/',
#    'maxPrice': 13500,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/368/10010004560313591368_1.jpg?_ex=128x128',
#    'minPrice': 13500,
#    'productCaption': '',
#    'productId': '8be60488585499ffca36aca925cfe848',
#    'productName': '今治タオル バスローブ ナンバーカラー レディース 04 バイオレット',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/8be60488585499ffca36aca925cfe848/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/8be60488585499ffca36aca925cfe848/',
#    'rank': 5613,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/8be60488585499ffca36aca925cfe848/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/8be60488585499ffca36aca925cfe848/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 13500,
#    'salesMinPrice': 13500,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/368/10010004560313591368_1.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 13500,
#    'usedExcludeMinPrice': 13500,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 13500,
#    'usedExcludeSalesMinPrice': 13500},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 26203,
#    'brandName': '',
#    'genreId': '565248',
#    'genreName': '冷蔵庫・冷凍庫用アクセサリー',
#    'itemCount': 8,
#    'makerCode': '104511895',
#    'makerName': '中忠',
#    'makerNameFormal': '中忠株式会社',
#    'makerNameKana': 'ナカチユウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/565248/104511895/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/565248/104511895/',
#    'maxPrice': 32947,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/511/895/024/003/10010004511895024003_1.jpg?_ex=128x128',
#    'minPrice': 21458,
#    'productCaption': '',
#    'productId': 'c62188f82bebb8e5e4c7b2c2280da3a4',
#    'productName': '極ふわ やさしいたおる‐premium‐ バスローブ グレー',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/c62188f82bebb8e5e4c7b2c2280da3a4/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/c62188f82bebb8e5e4c7b2c2280da3a4/',
#    'rank': 1049,
#    'rankTargetGenreId': '565080',
#    'rankTargetProductCount': 5218,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/c62188f82bebb8e5e4c7b2c2280da3a4/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/c62188f82bebb8e5e4c7b2c2280da3a4/review/',
#    'salesItemCount': 4,
#    'salesMaxPrice': 25840,
#    'salesMinPrice': 21458,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/511/895/024/003/10010004511895024003_1.jpg?_ex=64x64',
#    'usedExcludeCount': 8,
#    'usedExcludeMaxPrice': 32947,
#    'usedExcludeMinPrice': 21458,
#    'usedExcludeSalesItemCount': 4,
#    'usedExcludeSalesMaxPrice': 25840,
#    'usedExcludeSalesMinPrice': 21458},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 10023,
#    'brandName': '',
#    'genreId': '207733',
#    'genreName': 'バスローブ',
#    'itemCount': 4,
#    'makerCode': '10456010985',
#    'makerName': 'オルネット',
#    'makerNameFormal': '株式会社オルネット',
#    'makerNameKana': 'オルネツト',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/207733/10456010985/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/207733/10456010985/',
#    'maxPrice': 12070,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/323/279/160/10010004571323279160_1.jpg?_ex=128x128',
#    'minPrice': 9337,
#    'productCaption': '',
#    'productId': 'b445ef7a588baa7bbbc400bd50eebe23',
#    'productName': '今治タオル オーディア パイルバスローブ 90 imabaritowel /ベビーバスローブ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/b445ef7a588baa7bbbc400bd50eebe23/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/b445ef7a588baa7bbbc400bd50eebe23/',
#    'rank': 295,
#    'rankTargetGenreId': '568292',
#    'rankTargetProductCount': 383,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/b445ef7a588baa7bbbc400bd50eebe23/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/b445ef7a588baa7bbbc400bd50eebe23/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 12070,
#    'salesMinPrice': 12070,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/323/279/160/10010004571323279160_1.jpg?_ex=64x64',
#    'usedExcludeCount': 4,
#    'usedExcludeMaxPrice': 12070,
#    'usedExcludeMinPrice': 9337,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 12070,
#    'usedExcludeSalesMinPrice': 12070},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 14040,
#    'brandName': '',
#    'genreId': '304015',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '10456031359',
#    'makerName': '田中産業',
#    'makerNameFormal': '田中産業株式会社',
#    'makerNameKana': 'タナカサンギヨウ',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/304015/10456031359/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/304015/10456031359/',
#    'maxPrice': 14040,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/313/10010004560313591313_1.jpg?_ex=128x128',
#    'minPrice': 14040,
#    'productCaption': '',
#    'productId': '330ed0a9ee81deda1fcd844ffcc2b5d2',
#    'productName': '今治タオル バスローブ ナンバーカラー メンズ 11 ラベンダー',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/330ed0a9ee81deda1fcd844ffcc2b5d2/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/330ed0a9ee81deda1fcd844ffcc2b5d2/',
#    'rank': 1164,
#    'rankTargetGenreId': '304013',
#    'rankTargetProductCount': 1272,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/330ed0a9ee81deda1fcd844ffcc2b5d2/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/330ed0a9ee81deda1fcd844ffcc2b5d2/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 14040,
#    'salesMinPrice': 14040,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/313/591/313/10010004560313591313_1.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 14040,
#    'usedExcludeMinPrice': 14040,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 14040,
#    'usedExcludeSalesMinPrice': 14040},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 31900,
#    'brandName': '',
#    'genreId': '101877',
#    'genreName': 'その他',
#    'itemCount': 3,
#    'makerCode': '0',
#    'makerName': '',
#    'makerNameFormal': '',
#    'makerNameKana': '',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/101877/0/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/101877/0/',
#    'maxPrice': 31900,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/3001/0005/722/000/130/628/30010005722000130628_1.jpg?_ex=128x128',
#    'minPrice': 31900,
#    'productCaption': '',
#    'productId': '300b028d241260fd94b1c522231aeed5',
#    'productName': 'ゾーン バスローブ パジャマ 寝巻 13062',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/300b028d241260fd94b1c522231aeed5/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/300b028d241260fd94b1c522231aeed5/',
#    'rank': 0,
#    'rankTargetGenreId': '0',
#    'rankTargetProductCount': 0,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/300b028d241260fd94b1c522231aeed5/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/300b028d241260fd94b1c522231aeed5/review/',
#    'salesItemCount': 3,
#    'salesMaxPrice': 31900,
#    'salesMinPrice': 31900,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/3001/0005/722/000/130/628/30010005722000130628_1.jpg?_ex=64x64',
#    'usedExcludeCount': 3,
#    'usedExcludeMaxPrice': 31900,
#    'usedExcludeMinPrice': 31900,
#    'usedExcludeSalesItemCount': 3,
#    'usedExcludeSalesMaxPrice': 31900,
#    'usedExcludeSalesMinPrice': 31900},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 240000,
#    'brandName': '',
#    'genreId': '408069',
#    'genreName': '岩盤浴マット',
#    'itemCount': 10,
#    'makerCode': '10457146133',
#    'makerName': '梅研本舗ジャパン',
#    'makerNameFormal': '梅研本舗ジャパン株式会社',
#    'makerNameKana': 'ウメケンホンポジヤパン',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/408069/10457146133/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/408069/10457146133/',
#    'maxPrice': 270000,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/461/330/846/10010004571461330846_1.jpg?_ex=128x128',
#    'minPrice': 210000,
#    'productCaption': '',
#    'productId': 'c74c9af12e693456cff9b680645f8377',
#    'productName': 'ウィンストーン岩盤浴ベッド台座  大判バスタオル',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/c74c9af12e693456cff9b680645f8377/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/c74c9af12e693456cff9b680645f8377/',
#    'rank': 21205,
#    'rankTargetGenreId': '408067',
#    'rankTargetProductCount': 40488,
#    'releaseDate': '',
#    'reviewAverage': 5,
#    'reviewCount': 4,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/c74c9af12e693456cff9b680645f8377/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/c74c9af12e693456cff9b680645f8377/review/',
#    'salesItemCount': 10,
#    'salesMaxPrice': 270000,
#    'salesMinPrice': 210000,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/571/461/330/846/10010004571461330846_1.jpg?_ex=64x64',
#    'usedExcludeCount': 10,
#    'usedExcludeMaxPrice': 270000,
#    'usedExcludeMinPrice': 210000,
#    'usedExcludeSalesItemCount': 10,
#    'usedExcludeSalesMaxPrice': 270000,
#    'usedExcludeSalesMinPrice': 210000},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 14850,
#    'brandName': 'LBC',
#    'genreId': '112779',
#    'genreName': 'その他',
#    'itemCount': 1,
#    'makerCode': '0',
#    'makerName': '',
#    'makerNameFormal': '',
#    'makerNameKana': '',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/112779/0/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/112779/0/',
#    'maxPrice': 14850,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/9001/1001/000/013/868/402/90011001000013868402_1.jpg?_ex=128x128',
#    'minPrice': 14850,
#    'productCaption': '',
#    'productId': '5541017089a7f2afca20d6dfa523c124',
#    'productName': 'tower タワー 立て掛けランドリーシェルフ',
#    'productNo': 'M48329_30498909',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/5541017089a7f2afca20d6dfa523c124/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/5541017089a7f2afca20d6dfa523c124/',
#    'rank': 0,
#    'rankTargetGenreId': '0',
#    'rankTargetProductCount': 0,
#    'releaseDate': '2015年4月28日',
#    'reviewAverage': 5,
#    'reviewCount': 1,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/5541017089a7f2afca20d6dfa523c124/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/5541017089a7f2afca20d6dfa523c124/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 14850,
#    'salesMinPrice': 14850,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/9001/1001/000/013/868/402/90011001000013868402_1.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 14850,
#    'usedExcludeMinPrice': 14850,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 14850,
#    'usedExcludeSalesMinPrice': 14850},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 468000,
#    'brandName': '',
#    'genreId': '408069',
#    'genreName': '岩盤浴マット',
#    'itemCount': 5,
#    'makerCode': '10457146133',
#    'makerName': '梅研本舗ジャパン',
#    'makerNameFormal': '梅研本舗ジャパン株式会社',
#    'makerNameKana': 'ウメケンホンポジヤパン',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/408069/10457146133/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/408069/10457146133/',
#    'maxPrice': 468000,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 468000,
#    'productCaption': '',
#    'productId': 'fa8d787ec995af8ce00c6a423f2704c4',
#    'productName': '桜島溶岩浴ベッド 台座セット',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/fa8d787ec995af8ce00c6a423f2704c4/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/fa8d787ec995af8ce00c6a423f2704c4/',
#    'rank': 21207,
#    'rankTargetGenreId': '408067',
#    'rankTargetProductCount': 40488,
#    'releaseDate': '',
#    'reviewAverage': 5,
#    'reviewCount': 2,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/fa8d787ec995af8ce00c6a423f2704c4/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/fa8d787ec995af8ce00c6a423f2704c4/review/',
#    'salesItemCount': 5,
#    'salesMaxPrice': 468000,
#    'salesMinPrice': 468000,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 5,
#    'usedExcludeMaxPrice': 468000,
#    'usedExcludeMinPrice': 468000,
#    'usedExcludeSalesItemCount': 5,
#    'usedExcludeSalesMaxPrice': 468000,
#    'usedExcludeSalesMinPrice': 468000},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 18480,
#    'brandName': '',
#    'genreId': '205222',
#    'genreName': 'ギフトセット',
#    'itemCount': 1,
#    'makerCode': '10458998053',
#    'makerName': 'ノアド',
#    'makerNameFormal': '有限会社ノアド',
#    'makerNameKana': 'ノアド',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/205222/10458998053/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/205222/10458998053/',
#    'maxPrice': 18480,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 18480,
#    'productCaption': '',
#    'productId': 'eb87d1a06e4efc833ea97addbc4c9737',
#    'productName': '出産祝い オーガニック 親子ペア バスローブセット',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/eb87d1a06e4efc833ea97addbc4c9737/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/eb87d1a06e4efc833ea97addbc4c9737/',
#    'rank': 573,
#    'rankTargetGenreId': '205222',
#    'rankTargetProductCount': 988,
#    'releaseDate': '',
#    'reviewAverage': 4.41,
#    'reviewCount': 34,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/eb87d1a06e4efc833ea97addbc4c9737/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/eb87d1a06e4efc833ea97addbc4c9737/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 18480,
#    'salesMinPrice': 18480,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 18480,
#    'usedExcludeMinPrice': 18480,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 18480,
#    'usedExcludeSalesMinPrice': 18480},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 17160,
#    'brandName': '',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '104547561',
#    'makerName': '丸栄タオル',
#    'makerNameFormal': '丸栄タオル株式会社',
#    'makerNameKana': 'マルエイタオル',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/104547561/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/104547561/',
#    'maxPrice': 17160,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 17160,
#    'productCaption': '',
#    'productId': 'ef64c58cd7e96e1dd2e30f969c7e108a',
#    'productName': '吸湿性に優れ肌触りのよいワッフルバスローブ アイボリー',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/ef64c58cd7e96e1dd2e30f969c7e108a/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/ef64c58cd7e96e1dd2e30f969c7e108a/',
#    'rank': 5521,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 4.5,
#    'reviewCount': 4,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/ef64c58cd7e96e1dd2e30f969c7e108a/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/ef64c58cd7e96e1dd2e30f969c7e108a/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 17160,
#    'salesMinPrice': 17160,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 17160,
#    'usedExcludeMinPrice': 17160,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 17160,
#    'usedExcludeSalesMinPrice': 17160},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 13200,
#    'brandName': 'デアアフェット',
#    'genreId': '510870',
#    'genreName': 'バスローブ',
#    'itemCount': 1,
#    'makerCode': '10458007505',
#    'makerName': 'アフェット',
#    'makerNameFormal': '株式会社アフェット',
#    'makerNameKana': 'アフエツト',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/510870/10458007505/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/510870/10458007505/',
#    'maxPrice': 13200,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 13200,
#    'productCaption': '',
#    'productId': '3f6329d133119f07ed2fa652479086c1',
#    'productName': 'デアアフェット スリムバスローブ ベージュ',
#    'productNo': 'AFBT01-0001',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/3f6329d133119f07ed2fa652479086c1/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/3f6329d133119f07ed2fa652479086c1/',
#    'rank': 5858,
#    'rankTargetGenreId': '206746',
#    'rankTargetProductCount': 6237,
#    'releaseDate': '',
#    'reviewAverage': 5,
#    'reviewCount': 2,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/3f6329d133119f07ed2fa652479086c1/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/3f6329d133119f07ed2fa652479086c1/review/',
#    'salesItemCount': 1,
#    'salesMaxPrice': 13200,
#    'salesMinPrice': 13200,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 1,
#    'usedExcludeMaxPrice': 13200,
#    'usedExcludeMinPrice': 13200,
#    'usedExcludeSalesItemCount': 1,
#    'usedExcludeSalesMaxPrice': 13200,
#    'usedExcludeSalesMinPrice': 13200},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 308000,
#    'brandName': '',
#    'genreId': '408069',
#    'genreName': '岩盤浴マット',
#    'itemCount': 3,
#    'makerCode': '10457146133',
#    'makerName': '梅研本舗ジャパン',
#    'makerNameFormal': '梅研本舗ジャパン株式会社',
#    'makerNameKana': 'ウメケンホンポジヤパン',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/408069/10457146133/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/408069/10457146133/',
#    'maxPrice': 308000,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 308000,
#    'productCaption': '',
#    'productId': 'a20c2b4f1fb003eb02804abdf67c7289',
#    'productName': 'オリジナル岩盤浴ベッド台座セット・大判バスタオル・バスローブ付き',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/a20c2b4f1fb003eb02804abdf67c7289/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/a20c2b4f1fb003eb02804abdf67c7289/',
#    'rank': 21206,
#    'rankTargetGenreId': '408067',
#    'rankTargetProductCount': 40488,
#    'releaseDate': '',
#    'reviewAverage': 4.8,
#    'reviewCount': 10,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/a20c2b4f1fb003eb02804abdf67c7289/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/a20c2b4f1fb003eb02804abdf67c7289/review/',
#    'salesItemCount': 3,
#    'salesMaxPrice': 308000,
#    'salesMinPrice': 308000,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 3,
#    'usedExcludeMaxPrice': 308000,
#    'usedExcludeMinPrice': 308000,
#    'usedExcludeSalesItemCount': 3,
#    'usedExcludeSalesMaxPrice': 308000,
#    'usedExcludeSalesMinPrice': 308000},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 15119,
#    'brandName': 'エアーかおる',
#    'genreId': '551732',
#    'genreName': 'バスタオル',
#    'itemCount': 9,
#    'makerCode': '10456010158',
#    'makerName': 'タグ・ホールディングス',
#    'makerNameFormal': '株式会社タグ・ホールディングス',
#    'makerNameKana': 'タグホールデイングス',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/551732/10456010158/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/551732/10456010158/',
#    'maxPrice': 15400,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/101/588/518/10010004560101588518_1.jpg?_ex=128x128',
#    'minPrice': 13475,
#    'productCaption': '',
#    'productId': '202a7488c5ec35ea491796de8ed4edcc',
#    'productName': 'エアーかおる 着るタオル シェルピンク(1枚)',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/202a7488c5ec35ea491796de8ed4edcc/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/202a7488c5ec35ea491796de8ed4edcc/',
#    'rank': 968,
#    'rankTargetGenreId': '551732',
#    'rankTargetProductCount': 2790,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/202a7488c5ec35ea491796de8ed4edcc/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/202a7488c5ec35ea491796de8ed4edcc/review/',
#    'salesItemCount': 6,
#    'salesMaxPrice': 15400,
#    'salesMinPrice': 13475,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/1001/0004/560/101/588/518/10010004560101588518_1.jpg?_ex=64x64',
#    'usedExcludeCount': 9,
#    'usedExcludeMaxPrice': 15400,
#    'usedExcludeMinPrice': 13475,
#    'usedExcludeSalesItemCount': 6,
#    'usedExcludeSalesMaxPrice': 15400,
#    'usedExcludeSalesMinPrice': 13475},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 30800,
#    'brandName': '',
#    'genreId': '101833',
#    'genreName': 'その他',
#    'itemCount': 2,
#    'makerCode': '10458988209',
#    'makerName': 'リカトレーディングビューロー(同)',
#    'makerNameFormal': 'リカトレーディングビューロー(同)',
#    'makerNameKana': 'リカトレーデイングビユーロー',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/101833/10458988209/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/101833/10458988209/',
#    'maxPrice': 30800,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 30800,
#    'productCaption': '',
#    'productId': '61f24451534fc50dc8ae23838ede7600',
#    'productName': 'LuinSpa/ルインスパ バスローブ/Sサイズ 低撚糸コットン贅沢バスローブ ROBS-BE バスグッズ お風呂 タオル モコモコ フワフワ 高級 メンズ レディース ユニセックス ベビー キッズ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/61f24451534fc50dc8ae23838ede7600/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/61f24451534fc50dc8ae23838ede7600/',
#    'rank': 5979,
#    'rankTargetGenreId': '101833',
#    'rankTargetProductCount': 11419,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/61f24451534fc50dc8ae23838ede7600/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/61f24451534fc50dc8ae23838ede7600/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 30800,
#    'salesMinPrice': 30800,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 30800,
#    'usedExcludeMinPrice': 30800,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 30800,
#    'usedExcludeSalesMinPrice': 30800},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 30800,
#    'brandName': '',
#    'genreId': '101833',
#    'genreName': 'その他',
#    'itemCount': 2,
#    'makerCode': '10458988209',
#    'makerName': 'リカトレーディングビューロー(同)',
#    'makerNameFormal': 'リカトレーディングビューロー(同)',
#    'makerNameKana': 'リカトレーデイングビユーロー',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/101833/10458988209/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/101833/10458988209/',
#    'maxPrice': 30800,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 30800,
#    'productCaption': '',
#    'productId': 'a854692a083b771179e9cfd9a18edb95',
#    'productName': 'LuinSpa/ルインスパ バスローブ/ユニセックスMサイズ 低撚糸コットン贅沢バスローブ ROBS-BE バスグッズ お風呂 タオル モコモコ フワフワ 高級 メンズ レディース ユニセックス ベビー キッズ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/a854692a083b771179e9cfd9a18edb95/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/a854692a083b771179e9cfd9a18edb95/',
#    'rank': 5982,
#    'rankTargetGenreId': '101833',
#    'rankTargetProductCount': 11419,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/a854692a083b771179e9cfd9a18edb95/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/a854692a083b771179e9cfd9a18edb95/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 30800,
#    'salesMinPrice': 30800,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 30800,
#    'usedExcludeMinPrice': 30800,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 30800,
#    'usedExcludeSalesMinPrice': 30800},
#   {'ProductDetails': [],
#    'affiliateUrl': None,
#    'averagePrice': 30800,
#    'brandName': '',
#    'genreId': '101833',
#    'genreName': 'その他',
#    'itemCount': 2,
#    'makerCode': '10458988209',
#    'makerName': 'リカトレーディングビューロー(同)',
#    'makerNameFormal': 'リカトレーディングビューロー(同)',
#    'makerNameKana': 'リカトレーデイングビユーロー',
#    'makerPageUrlMobile': 'http://m.product.rakuten.co.jp/category/101833/10458988209/',
#    'makerPageUrlPC': 'https://product.rakuten.co.jp/category/-/101833/10458988209/',
#    'maxPrice': 30800,
#    'mediumImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=128x128',
#    'minPrice': 30800,
#    'productCaption': '',
#    'productId': 'fcc0117a07fe591ad3ef0db15c3ac9de',
#    'productName': 'LuinSpa/ルインスパ バスローブ/ユニセックスMサイズ 低撚糸コットン贅沢バスローブ ROBS-BL バスグッズ お風呂 タオル モコモコ フワフワ 高級 メンズ レディース ユニセックス ベビー キッズ',
#    'productNo': '',
#    'productUrlMobile': 'http://m.product.rakuten.co.jp/product/fcc0117a07fe591ad3ef0db15c3ac9de/',
#    'productUrlPC': 'https://product.rakuten.co.jp/product/-/fcc0117a07fe591ad3ef0db15c3ac9de/',
#    'rank': 5984,
#    'rankTargetGenreId': '101833',
#    'rankTargetProductCount': 11419,
#    'releaseDate': '',
#    'reviewAverage': 0,
#    'reviewCount': 0,
#    'reviewUrlMobile': 'http://m.product.rakuten.co.jp/product/fcc0117a07fe591ad3ef0db15c3ac9de/review/',
#    'reviewUrlPC': 'https://product.rakuten.co.jp/product/-/fcc0117a07fe591ad3ef0db15c3ac9de/review/',
#    'salesItemCount': 2,
#    'salesMaxPrice': 30800,
#    'salesMinPrice': 30800,
#    'smallImageUrl': 'https://thumbnail.image.rakuten.co.jp/ran/img/default/now_printing.jpg?_ex=64x64',
#    'usedExcludeCount': 2,
#    'usedExcludeMaxPrice': 30800,
#    'usedExcludeMinPrice': 30800,
#    'usedExcludeSalesItemCount': 2,
#    'usedExcludeSalesMaxPrice': 30800,
#    'usedExcludeSalesMinPrice': 30800}],
#  'count': 58,
#  'first': 1,
#  'hits': 30,
#  'last': 30,
#  'page': 1,
#  'pageCount': 2}

# %%
items = result['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kii/work/python/python-study/python-web-api/rakuten_api/main.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kii/work/python/python-study/python-web-api/rakuten_api/main.ipynb#ch0000006?line=0'>1</a> items = result['items']
#
# KeyError: 'items'
