# %%
# 必要なライブラリのインポート
from bs4 import BeautifulSoup
import pandas as pd
import requests
import datetime as dt
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# パスの取得に必要なリストの定義
new_path = []
path = []

# データフレームの作成に必要なリストの定義
update_date_list = []
house_image_list = []
address_list = []
distance_list = []
year_list = []
level_list = []
room_image_list = []
rent_price_list = []
admin_price_list = []
deposit_price_list = []
key_price_list = []
size_list = []
area_list = []
url_list = []

# 今日の日付
today = format(dt.datetime.today(),'%Y/%m/%d')

# SUUMOの検索ページ（指定済みURL）
url = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ra=014&cb=0.0&ct=10.0&co=1&et=15&md=09&md=10&md=11&md=12&md=13&md=14&cn=9999999&mb=45&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&ek=016026210&rn=0160'

# 住宅ごと
elems = soup.find_all('div', class_='cassetteitem')
for index, elem in enumerate(elems):

    # 部屋ごと
    elems_room = elem.find_all('tr', class_='js-cassette_link')
    for elem_room in elems_room:

        # 更新日
        update_date_list.append(today)

        # 家の画像
        house_image_list.append(elem.find('img', class_='js-linkImage')['rel'])

        # 住所
        address_list.append(elem.find('li', class_='cassetteitem_detail-col1').text)

        # 駅徒歩
        distance_list.append(elem.find('div', class_='cassetteitem_detail-text').text)

        # 築年数と階層
        elem1 = elem.find('li', class_='cassetteitem_detail-col3')
        # 築年数
        year_list.append(elem1.find_all('div')[0].text)
        # 階層
        level_list.append(elem1.find_all('div')[1].text)
        
        # 間取り図
        room_image_list.append(elem_room.find('img')['rel'])

        # 賃料
        rent_price_list.append(elem_room.find('span', class_='cassetteitem_other-emphasis').text)

        # 管理費
        admin_price_list.append(elem_room.find('span', class_='cassetteitem_price--administration').text)

        # 敷金
        deposit_price_list.append(elem_room.find('span', class_='cassetteitem_price--deposit').text)

        # 礼金
        key_price_list.append(elem_room.find('span', class_='cassetteitem_price--gratuity').text)

        # 間取り
        size_list.append(elem_room.find('span', class_='cassetteitem_madori').text)
        
        # 占有面積
        area_list.append(elem_room.find('span', class_='cassetteitem_menseki').text)

        # 詳細リンク取得
        url_list.append('https://suumo.jp' + elem_room.find('a', class_='js-cassette_link_href')['href'])

# データフレーム作成
df = pd.DataFrame()

df['更新日'] = update_date_list
df['家の写真'] = house_image_list
df['住所'] = address_list
df['駅徒歩'] = distance_list
df['築年数'] = year_list
df['階層'] = level_list
df['間取り図'] = room_image_list
df['賃料'] = rent_price_list
df['管理費'] = admin_price_list
df['敷金'] = deposit_price_list
df['礼金'] = key_price_list
df['間取り'] = size_list
df['占有面積'] = area_list
df['詳細リンク取得'] = url_list

# CSVファイル出力
# df.to_csv(f'./output/SUUMO.csv', index=False)


# スプレッドシート連携
# creds を使って Google Drive API と対話するためのクライアントを作成
scope =['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name(r'./python-spread.json', scope)
client = gspread.authorize(creds)

# ワークブックを検索、最初のシートを開く
worksheet = client.open("SUUMOスクレイピング").sheet1

# すべての値を取得
list_of_hashes = worksheet.get_all_records()

# スプレッドシートのデータフレーム作成
df_sp = pd.DataFrame()
df_sp = pd.DataFrame(list_of_hashes)

# 帝国スクレイピングとスプシのデータ統合
df_con = pd.concat([df,df_sp])

# スプレッドシートのデータ更新

set_with_dataframe(worksheet, df_con.reset_index(drop=True))

print('更新完了')

# %%
# スプレッドシート連携
# creds を使って Google Drive API と対話するためのクライアントを作成
scope =['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name(r'./python-spread.json', scope)
client = gspread.authorize(creds)

# ワークブックを検索、最初のシートを開く
worksheet = client.open("SUUMOスクレイピング").sheet1

# すべての値を取得
list_of_hashes = worksheet.get_all_records()

# スプレッドシートのデータフレーム作成
df_sp = pd.DataFrame()
df_sp = pd.DataFrame(list_of_hashes)

# 帝国スクレイピングとスプシのデータ統合
df_con = pd.concat([df,df_sp])

# スプレッドシートのデータ更新

set_with_dataframe(worksheet, df_con.reset_index(drop=True))

print('更新完了')
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]><html lang="ja" class="ie"><![endif]-->
# <!--[if IE 7]><html lang="ja" class="ie"><![endif]-->
# <!--[if IE 8]><html lang="ja" class="ie"><![endif]-->
# <!--[if gt IE 8]><!--><html lang="ja"><!--<![endif]-->
# <!-- FR301FC0012 START -->
# <head>
# <meta charset="utf-8"/>
# <!-- seo.headerTag Start -->
# <title>【SUUMO】戸塚駅の賃貸(賃貸マンション・アパート)住宅のお部屋探し物件情報（神奈川県）</title>
# <meta content="戸塚駅,神奈川県,賃貸,賃貸マンション,アパート,賃貸アパート,賃貸情報,部屋探し,賃貸住宅,物件,賃貸物件,住まい,SUUMO,スーモ" name="keywords"/>
# <meta content="【SUUMO(スーモ)賃貸】戸塚駅(神奈川県)周辺でアパート・賃貸マンションを借りるならリクルートの賃貸情報サイトSUUMO(スーモ)にお任せください。全国の賃貸住宅・貸家の物件情報からさまざまな条件を指定して検索！豊富な賃貸物件情報からあなたにピッタリの住まい情報を見つけてください。" name="description"/>
# <meta content="noindex, follow" name="robots"/>
# <link href="/front/img/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/front/img/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <meta content="noarchive" name="robots"/>
# <!-- seo.headerTag End -->
# <link href="/edit/assets/suumo/css/fr-list.css?1663028082000" media="screen" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <script src="/edit/assets/allsites/js/html5.js?1501566649000"></script>
# <![endif]-->
# <!-- GTMタグ用↓ -->
# <script type="text/javascript">
# var gapSuumoPcForIchiran = [{
# 	kamin : "",
# 	kamax : "",
# 	chinryomin : "0",
# 	chinryomax : "10",
# 	m : ["09","10","11","12","13","14"],
# 	menmin : "45",
# 	menmax : "9999999",
# 	nyukyo : "",
# 	se : ["040"],
# 	senm : ["賃貸"],
# 	newupdflg : "0",
# 	newupd3flg : "",
# 	newupd7flg : "",
# 	newupd2_7flg : "0",
# 	newflg : "",
# 	tanm : "神奈川県",
# 	scnm : [""],
# 	kibo : "",
# 	et : "15",
# 	bf : "",
# 	tmenmin : "",
# 	tmenmax : "",
# 	sa : [""],
# 	sc : [""],
# 	ta : "14",
# 	s : ["0160"],
# 	e : ["016026210"],
# 	km : "",
# 	cn : "9999999",
# 	areacd : "030",
# 	areanm : "関東",
# 	sckukuri1 : "14",
# 	sckukuri1nm : "神奈川県",
# 	sckukuri3 : [""],
# 	sckukuri3nm : [""],
# 	gamen_type : "10"
# }];
# //-->
# </script>
# <!-- GTMタグ用↑ -->
# <script src="/front/tag/stmt/stmt_head.js?1423704773000" type="text/javascript"></script>
# </head>
# <body>
# <form action="https://suumo.jp/jj/common/service/JJ901FM308/" id="js-kensakuJoukenTourokuForm" target="_blank">
# <input name="tbi4dbs" type="hidden" value="..."/>
# <input name="searchdisp" type="hidden" value="ＪＲ東海道本線／戸塚 10万円以下 3DK／3LDK／4K／4DK／4LDK／5K以上 15分以内 45m2以上 管理費・共益費込み">
# <input name="actionpath" type="hidden" value="/chintai/ichiran/FR301FC001/"/>
# <input name="shkr1" type="hidden" value="03"/>
# <input name="shkr3" type="hidden" value="03"/>
# <input name="cb" type="hidden" value="0.0"/>
# <input name="rn" type="hidden" value="0160"/>
# <input name="shkr2" type="hidden" value="03"/>
# <input name="mt" type="hidden" value="9999999"/>
# <input name="ar" type="hidden" value="030"/>
# <input name="bs" type="hidden" value="040"/>
# <input name="shkr4" type="hidden" value="03"/>
# <input name="ct" type="hidden" value="10.0"/>
# <input name="ra" type="hidden" value="014"/>
# <input name="co" type="hidden" value="1"/>
# <input name="cn" type="hidden" value="9999999"/>
# <input name="md" type="hidden" value="09"/>
# <input name="md" type="hidden" value="10"/>
# <input name="md" type="hidden" value="11"/>
# <input name="md" type="hidden" value="12"/>
# <input name="md" type="hidden" value="13"/>
# <input name="md" type="hidden" value="14"/>
# <input name="ek" type="hidden" value="016026210"/>
# <input name="mb" type="hidden" value="45"/>
# <input name="fw2" type="hidden" value=""/>
# <input name="et" type="hidden" value="15"/>
# </input></form>
# <!-- GlobalHeader01_01 Start -->
# <link href="/edit/assets/suumo/css/header-gnav.css?1550193296000" media="screen" rel="stylesheet preconnect"/>
# <form action="https://suumo.jp/jj/common/common/JJ901FK101/showLogin/" id="js-turnbackPostForm" method="post" name="common_common_JJ901FK101ActionForm"><input name="tbi4dbs" type="hidden" value="..."/>
# </form><form action="/jj/common/service/JJ901FM303/" id="js-myKensakuJokenForm" method="post">
# <input name="ar" type="hidden" value="030"/>
# <input name="bs" type="hidden" value="040"/>
# </form>
# <form action="/jj/common/parts/JJ901FI306/" id="js-popLatestBukkenForm" method="post">
# <input name="ar" type="hidden" value=""/>
# <input name="bs" type="hidden" value=""/>
# <input name="dispmode" type="hidden" value="3"/>
# </form>
# <form action="/jj/common/parts/JJ901FI302/" id="js-resetLatestBukkenForm" method="post">
# <input name="ar" type="hidden" value=""/>
# <input name="bs" type="hidden" value=""/>
# <input name="dispmode" type="hidden" value="3"/>
# </form>
# <form action="/jj/common/parts/JJ901FI313/" id="js-popLatestSearchForm" method="post">
# <input name="ar" type="hidden" value="030"/>
# <input name="bs" type="hidden" value=""/>
# <input name="dispmode" type="hidden" value="3"/>
# </form>
# <form action="/jj/common/parts/JJ901FI312/" id="js-resetLatestSearchForm" method="post">
# <input name="ar" type="hidden" value=""/>
# <input name="bs" type="hidden" value=""/>
# <input name="dispmode" type="hidden" value="3"/>
# </form>
# <form action="https://suumo.jp/jj/common/common/JJ901FK101/showMemRegist/" id="js-myEntryForm" method="post" name="common_common_JJ901FK101ActionForm"><input name="tbi4dbs" type="hidden" value="..."/>
# </form><div class="mylist" id="js-mylist">
# <div class="mylist-inner">
# <div class="browsearea dn" id="js-mylist-historyBox">
# <ul class="browselist">
# <li class="browselist-box" id="js-mylist-historyBox-popLatestBukken"></li>
# <li class="browselist-box" id="js-mylist-historyBox-popLatestSearch"></li>
# </ul>
# <div class="browsearea-close" id="js-mylist-historyBox-close">
# <a href="javascript:void(0);">× 閉じる</a>
# </div>
# </div>
# <div class="mylist-logo" id="js-mylist-logo">
# <a class="js-setCookieArZenkoku" href="/">suumo</a>
# </div>
# <ul class="mylist-list">
# <li>
# <div class="mylistbarbox">
# <div class="mylistbarbox-inner">
# <div class="mylistbarbox-inner-contents">
# <div class="mylistbar">
# <p class="mylistbar-title">お気に入り</p>
# <ul class="mylistbar-inbar">
# <li class="mylistbar-inbar-item">
# <a class="mylistbarlink mylistbarlink--bukken" href="/jj/common/service/JJ901FM203/?ar=030&amp;bs=040&amp;cts=01"><span class="mylistbarlink-title">物件</span><!--
# --><span class="mylistbarcnt" id="js-mylistbarcnt-bukken">
# </span></a></li>
# <li class="mylistbar-inbar-item">
# <a class="mylistbarlink mylistbarlink--company" href="/jj/common/service/JJ901FM203/?ar=030&amp;bs=040&amp;cts=02"><span class="mylistbarlink-title">会社</span><!--
# --><span class="mylistbarcnt" id="js-mylistbarcnt-company">
# </span></a></li>
# <li class="mylistbar-inbar-item">
# <a class="mylistbarlink mylistbarlink--sch" href="javascript:void(0);" id="js-mylist-myKensakuJoken">
# <span class="mylistbarlink-title">検索条件</span><!--
# --><span class="mylistbarcnt" id="js-mylistbarcnt-sch">
# </span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="mylistnbbox">
# <div class="mylistbar mylistbar--nb">
# <ul class="mylistbar-inbar">
# <li class="mylistbar-inbar-item"><a class="mylistbarlink mylistbarlink--browse" href="javascript:void(0);" id="js-mylist-myHistory"><span class="mylistbarlink-title">閲覧履歴</span><span class="mylistbarlink-arw mylisticon mylisticon--arw"></span></a></li>
# </ul>
# </div>
# </div>
# </li>
# <li>
# <ul class="mylist-member">
# <li><a class="member-entry js-member-entry" href="/jj/common/common/JJ901FK101/showMemRegist/"><span>会員登録</span></a></li>
# <li><a class="mylist-login js-mylist-login" href="/jj/common/common/JJ901FK101/showLogin/"><span>ログイン</span></a></li>
# </ul>
# </li>
# </ul>
# <span class="dn" id="js-mylistbukkencountcookie">"20230312195601:H:0"</span>
# <span class="dn" id="js-mylistkaishacountcookie">"20230312195601:H:0"</span>
# <span class="dn" id="js-mylistkensakujokencountcookie">"20230312195601:H:0"</span>
# </div>
# </div>
# <div class="headercontainer">
# <!-- smpBanner Start -->
# <!-- smpBanner End -->
# <noscript>
# <div class="headjsalart">
# <div class="headjsalart-coution ui-media">
# <span class="ui-icon--exclamation1 ui-media-object"></span>
# <div class="ui-media-body">
# <div class="headjsalart-title">本サイトはJavaScriptをオンにした状態でお使いください</div>
# <p class="headjsalart-txt">
# 						ブラウザのJavaScriptの設定が有効になっていません。JavaScriptが有効になっていないとすべての機能をお使いいただけないことがあります。（<a href="https://suumo.jp/help/guide.html" target="_blank">JavaScriptを有効にする方法</a>）
# 					</p>
# </div>
# </div>
# </div>
# </noscript>
# <div class="siteheadercontainer">
# <div class="siteheader">
# <div class="desc">
# <p class="desc-title">戸塚駅（神奈川県）周辺で賃貸住宅[賃貸マンション・賃貸アパート]を借りるなら、お部屋探し物件情報サイトSUUMO(スーモ)賃貸</p>
# </div>
# <div class="siteheader-inner">
# <div class="logo">
# <div class="logo-object">
# <a href="/"><img alt="SUUMO(スーモ)" height="46" src="/edit/assets/suumo/img/logo.png" width="138"/></a></div>
# <div class="logo-field">
# <div class="logo-field-link">
# <a class="js-setCookieArZenkoku" href="/">全国へ</a></div>
# <div class="logo-field-area">関東版</div>
# </div>
# </div>
# <div class="gnav">
# <ul class="gnav_list">
# <li>
# <dl class="gnav_item gnav_item--chintai">
# <dt class="gnav_item-title">借りる</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--chintai is-active" href="/chintai/" title="賃貸">賃貸</a></div>
# </dd>
# </dl>
# </li>
# <li>
# <dl class="gnav_item gnav_item--ms">
# <dt class="gnav_item-title">
# <a href="/ms/" title="マンションの購入">マンション</a>を買う
# 								</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--shinchiku gnav_btn--left" href="/ms/shinchiku/" title="新築マンションの購入（築1年以上未入居を含む）">新築</a></div>
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--chukomansion gnav_btn--right" href="/ms/chuko/" title="中古マンションの購入">中古</a></div>
# </dd>
# </dl>
# </li>
# <li>
# <dl class="gnav_item gnav_item--kodate">
# <dt class="gnav_item-title">一戸建てを買う</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--ikkodate gnav_btn--left" href="/ikkodate/" title="新築一戸建ての購入（築1年以上未入居・建築条件付土地を含む）">新築</a></div>
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--chukoikkodate gnav_btn--right" href="/chukoikkodate/" title="中古一戸建ての購入">中古</a></div>
# </dd>
# </dl>
# </li>
# <li>
# <dl class="gnav_item gnav_item--chumon">
# <dt class="gnav_item-title">建てる</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--chumon gnav_btn--left" href="/chumon/" title="注文住宅">注文住宅</a></div>
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--tochi gnav_btn--right" href="/tochi/" title="土地の購入">土地</a></div>
# </dd>
# </dl>
# </li>
# <li>
# <dl class="gnav_item gnav_item--reform">
# <dt class="gnav_item-title">リフォームする</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--reform" href="/remodel/" title="リフォーム">リフォーム</a></div>
# </dd>
# </dl>
# </li>
# <li>
# <dl class="gnav_item gnav_item--baikyaku">
# <dt class="gnav_item-title">売る</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--baikyaku" href="/baikyaku/" title="売却査定">売却査定</a></div>
# </dd>
# </dl>
# </li>
# <li>
# <dl class="gnav_item gnav_item--counter">
# <dt class="gnav_item-title">住まいの相談</dt>
# <dd class="gnav_item-definition">
# <div class="gnav_item-definition-list">
# <a class="gnav_btn gnav_btn--counter" href="https://www.suumocounter.jp/?vos=dsmcrecb20110926001" target="_blank" title="講座/相談">講座/相談</a>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="gnav_item gnav_item--kurashi">
# <div class="balloon_nav">
# <div class="balloon_nav-action">
# <div class="balloon_nav-action-link">
# <a class="gnav_btn gnav_btn--kurashi" href="javascript:void(0);" title="暮らし">暮らし</a>
# </div>
# <div class="balloon_nav-action-item">
# <div class="gnav_drop_list">
# <ul class="gnav_drop_list-item">
# <li><a class="gnav_drop gnav_drop--moving" href="http://hikkoshi.suumo.jp/" target="_blank" title="SUUMO引越し見積もり"><span class="gnav_drop-text">SUUMO引越し見積もり</span></a></li>
# <li><a class="gnav_drop gnav_drop--fp" href="https://www.suumocounter.jp/fp/?suit=STct20170606005" target="_blank" title="SUUMO家とお金の相談"><span class="gnav_drop-text">SUUMO家とお金の相談</span></a></li>
# </ul>
# <ul class="gnav_drop_list-item">
# <li><a class="gnav_drop gnav_drop--loan" href="https://finance.recruit.co.jp/quick/?utm_source=scomgnav&amp;utm_medium=link&amp;utm_campaign=ret181001xx01" target="_blank" title="スゴい速い住宅ローン審査"><span class="gnav_drop-text">スゴい速い住宅ローン審査</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- GlobalHeader01_01 End -->
# <!-- Pankuzu01_01 Start -->
# <div class="breadcrumb">
# <div class="breadcrumb-inner">
# <ol class="breadcrumb-list"><li><a class="js-setCookieArZenkoku" href="/">不動産・住宅サイト SUUMO</a></li><li> &gt; <a class="js-setCookieArZenkoku" href="/chintai/">賃貸</a></li><li> &gt; <a href="/chintai/kanagawa/">神奈川県</a></li><li> &gt; <a href="/chintai/kanagawa/sa_yokohama/">横浜市</a></li><li> &gt; <a href="/chintai/kanagawa/sc_yokohamashitotsuka/">戸塚区</a></li><li> &gt; 戸塚駅の賃貸情報</li></ol></div>
# </div>
# <script type="application/ld+json">
# 		{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"position":1,"@type":"ListItem","item":{"name":"不動産・住宅サイト SUUMO","@id":"/"}},{"position":2,"@type":"ListItem","item":{"name":"賃貸","@id":"/chintai/"}},{"position":3,"@type":"ListItem","item":{"name":"神奈川県","@id":"/chintai/kanagawa/"}},{"position":4,"@type":"ListItem","item":{"name":"横浜市","@id":"/chintai/kanagawa/sa_yokohama/"}},{"position":5,"@type":"ListItem","item":{"name":"戸塚区","@id":"/chintai/kanagawa/sc_yokohamashitotsuka/"}}]}</script>
# <!-- Pankuzu01_01 End -->
# <div class="dn" id="hiddenModalContent">
# <div id="js-jokenLightBoxPanel"></div>
# </div>
# <div class="wrapper">
# <div class="ui-section--h1">
# <div class="ui-section-header">
# <h1>戸塚駅から探す賃貸住宅[賃貸マンション・アパート]情報 検索結果</h1>
# </div>
# <div class="ui-section-body">
# <p class="pagecaption">戸塚駅（神奈川県）エリア62件の物件をご紹介！賃貸マンション・賃貸アパート・貸家などの賃貸住宅を借りるなら、お部屋探しのSUUMO（スーモ）。物件情報の他、戸塚駅の地域情報（口コミ）などお部屋探し・お家探しに役立つ情報を掲載。戸塚駅周辺の賃貸マンション・賃貸アパート情報探しをサポートします。</p>
# <div class="contents contents--type2">
# <div class="main">
# <span id="js-tabListViewForm" rel="/jj/chintai/ichiran/FR301FC005/?shkr1=03&amp;shkr3=03&amp;cb=0.0&amp;rn=0160&amp;shkr2=03&amp;mt=9999999&amp;ar=030&amp;bs=040&amp;shkr4=03&amp;ct=10.0&amp;ra=014&amp;co=1&amp;cn=9999999&amp;md=09&amp;md=10&amp;md=11&amp;md=12&amp;md=13&amp;md=14&amp;ek=016026210&amp;mb=45&amp;fw2=&amp;et=15"></span>
# <form action="/jj/chintai/ichiran/FR301FC001/" id="js-addMylistForm" method="post">
# <input name="ar" type="hidden" value="030">
# <input name="bs" type="hidden" value="040">
# <input class="mail_clp_change" name="clp" type="hidden" value="">
# <div id="hidden_post"></div>
# </input></input></input></form>
# <form action="https://suumo.jp/jj/chintai/shiryou/FR301FG001/" id="js-shiryouseikyuForm" method="post">
# <input name="ar" type="hidden" value="030">
# <input name="bs" type="hidden" value="040">
# <input name="gkf" type="hidden" value="0">
# <input name="smk" type="hidden" value="">
# <span id="js-bcSpanList"></span>
# <input name="turnBackInfo" type="hidden" value="..."/></input></input></input></input></form>
# <form id="kensakujokentoroku" method="post" name="kensakujokentoroku">
# <input class="seaf_change" name="seaf" type="hidden" value=""/>
# <input class="ksk_email_change" name="email" type="hidden" value=""/>
# <input name="actionpath" type="hidden" value="/chintai/ichiran/FR301FC001/"/>
# <input name="searchdisp" type="hidden" value="ＪＲ東海道本線／戸塚 10万円以下 3DK／3LDK／4K／4DK／4LDK／5K以上 15分以内 45m2以上 管理費・共益費込み"/>
# <input name="shkr1" type="hidden" value="03">
# <input name="shkr3" type="hidden" value="03">
# <input name="cb" type="hidden" value="0.0">
# <input name="rn" type="hidden" value="0160">
# <input name="shkr2" type="hidden" value="03">
# <input name="mt" type="hidden" value="9999999">
# <input name="ar" type="hidden" value="030">
# <input name="bs" type="hidden" value="040">
# <input name="shkr4" type="hidden" value="03">
# <input name="ct" type="hidden" value="10.0">
# <input name="ra" type="hidden" value="014">
# <input name="co" type="hidden" value="1">
# <input name="cn" type="hidden" value="9999999"/>
# <input name="md" type="hidden" value="09"/>
# <input name="md" type="hidden" value="10"/>
# <input name="md" type="hidden" value="11"/>
# <input name="md" type="hidden" value="12"/>
# <input name="md" type="hidden" value="13"/>
# <input name="md" type="hidden" value="14"/>
# <input name="ek" type="hidden" value="016026210"/>
# <input name="mb" type="hidden" value="45"/>
# <input name="fw2" type="hidden" value=""/>
# <input name="et" type="hidden" value="15"/>
# </input></input></input></input></input></input></input></input></input></input></input></input></form>
# <form action="/jj/chintai/ichiran/FR301FC001/" id="js-leftColumnForm" method="post" name="chintai_ichiran_FR301FC001ActionForm"><input name="ar" type="hidden" value="030"/>
# <input class="mail_clp_change" name="clp" type="hidden" value=""/>
# <input name="bs" type="hidden" value="040"/>
# <div id="hidden_post"></div>
# <input disabled="disabled" id="kskbnId" type="hidden" value="01">
# <input disabled="disabled" id="js-dseFlgId" type="hidden" value="0">
# <div class="tabmenu tabmenu--04">
# <ul class="ui-tab--base ui-tab--base01 ui-tab--nolink">
# <li class="is-active">
# <div class="ui-tab-item">
# <span class="fr_list-eachicon fr_list-eachicon--building"></span>建物ごとに表示
# 									</div>
# </li>
# <li id="js-tabListView1">
# <div class="ui-tab-item">
# <span class="fr_list-eachicon fr_list-eachicon--door"></span>部屋ごとに表示
# 									</div>
# </li>
# </ul>
# <a class="dn" href="/jj/chintai/ichiran/FR301FC001/?ar=030&amp;bs=040&amp;ra=014&amp;rn=0160&amp;ek=016026210&amp;cb=0.0&amp;ct=10.0&amp;mb=45&amp;mt=9999999&amp;md=09&amp;md=10&amp;md=11&amp;md=12&amp;md=13&amp;md=14&amp;et=15&amp;cn=9999999&amp;co=1&amp;shkr1=03&amp;shkr2=03&amp;shkr3=03&amp;shkr4=03&amp;sngz=&amp;po1=25" id="js-pcLink"></a>
# </div>
# <!-- FrBukkenSort03 START -->
# <div class="selectbox">
# <input disabled="disabled" id="_po1" type="hidden" value="25"/>
# <input id="smk" type="hidden" value=""/>
# <input disabled="disabled" id="_po2" type="hidden" value="99"/>
# <div class="dn selectbox" id="FR301FK0041_OPTIONS"><ul>
# <li id="25">おすすめ順</li>
# <li id="12">賃料+管理費が安い順</li>
# <li id="15">賃料+管理費が高い順</li>
# <li id="09">新着順</li>
# <li id="04">築年数が新しい順</li>
# <li id="16">専有面積が広い順</li>
# <li id="17">住所別</li>
# </ul></div>
# <div class="paginate_set">
# <div class="paginate_set-hit">
# 			62<span>件</span>
# <span class="fr_list-eachicon fr_list-eachicon--info paginate_setitem">
# <span class="paginate_setitem-tip">不動産会社が掲載している物件総数です。
# 				<br/>SUUMOでは、同一と思われる物件を１つにまとめて表示しているため、
# 				<br/>掲載物件総数と物件一覧に表示されている件数が異なる場合があります。
# 				</span>
# </span>
# </div>
# </div>
# <dl>
# <dt>並び替え：</dt>
# <dd>
# <select class="sortbox-parts" id="js-sortbox-sortPulldownSingle" name="po1"><option id="opt1_25" selected="selected" value="25">おすすめ順</option><option id="opt1_12" value="12">賃料+管理費が安い順</option><option id="opt1_15" value="15">賃料+管理費が高い順</option><option id="opt1_09" value="09">新着順</option><option id="opt1_04" value="04">築年数が新しい順</option><option id="opt1_16" value="16">専有面積が広い順</option><option id="opt1_17" value="17">住所別</option></select></dd>
# <dt>表示建物数：</dt>
# <dd>
# <select id="js-tabmenu1-pcChange" name="pc"><option value="10">10件</option><option value="20">20件</option><option selected="selected" value="30">30件</option><option value="50">50件</option></select></dd>
# </dl>
# </div>
# <!-- FrBukkenSort03 END -->
# <!-- FrBukkenCassette03 START -->
# <div class="inquiry inquiry--top">
# <div class="inquiry_item">
# <div class="inquiry_item-title"><span class="fr_list-eachicon fr_list-eachicon--check_inquiry inquiry_item-title-text"></span>チェックした物件を</div>
# <div class="inquiry_item-btn"><a class="ui-btn ui-btn--cta2 ui-btn--small listbtn--small js-allShiryoSeikyu" href="javascript:void(0);" onclick="sendBeaconSiteCatalystClick(event,this,'hankyo_list_button',self);return false;" title="問い合わせする">まとめて問い合わせする</a></div>
# </div>
# </div>
# <div id="js-bukkenList">
# <div id="js-view_gallery">
# <div class="modalview_overlay" id="js-view_gallery-overlay"></div>
# <div class="l-modalview js-noContextMenu" id="js-view_gallery-modalview">
# <div class="modalview">
# <div class="modalview-main">
# <div class="modalview-main-close"><a class="modalview_close" href="javascript:void(0);" id="js-view_gallery-overlay_close"></a></div>
# <div class="modalview-main-prev"><a class="modalview_prev" href="javascript:void(0);" id="js-view_gallery-modalview_prev"></a></div>
# <div class="modalview-main-list">
# <ul class="l-modalview_object" id="js-view_gallery-modalview_list">
# <li>
# <div class="js-view_gallery-modalview_object modalview_object is-active">
# <div class="modalview_object-item is-loading">
# <img src="/edit/assets/suumo/img/fr_list_modal_now_print.png"/>
# <img src="/edit/assets/suumo/img/fr_list_modal_top_loading.png"/>
# </div>
# </div>
# </li>
# </ul>
# <div class="modalview-main-next"><a class="modalview_next" href="javascript:void(0);" id="js-view_gallery-modalview_next"></a></div>
# </div>
# <div class="modalview_btn">
# <a class="modalview_btn-link" href="" id="js-view_gallery-modalview_link" target="_blank">物件の詳細はこちら</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <ul class="l-cassetteitem">
# <li>
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸マンション</span></div>
# <div class="cassetteitem_content-title">ＪＲ東海道本線 戸塚駅 4階建 築35年</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">神奈川県横浜市戸塚区上倉田町</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ東海道本線/戸塚駅 歩15分</div>
# <div class="cassetteitem_detail-text">ブルーライン/舞岡駅 歩17分</div>
# <div class="cassetteitem_detail-text">ブルーライン/下永谷駅 歩29分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築35年</div>
# <div>4階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cassetteitem-item">
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox cassetteitem_other-checkbox--newarrival js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100320004332"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_s6o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											3階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">8.3万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">8.3万円</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">8.3万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">3DK</span></li>
# <li><span class="cassetteitem_menseki">58m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# <li><span class="cassetteitem-tag">パノラマ</span></li>
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100320004332">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000081000448/?bc=100320004332" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </li>
# <li>
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸マンション</span></div>
# <div class="cassetteitem_content-title">グランディオーズマンション</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">神奈川県横浜市戸塚区上倉田町</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ東海道本線/戸塚駅 歩15分</div>
# <div class="cassetteitem_detail-text">ブルーライン/舞岡駅 歩17分</div>
# <div class="cassetteitem_detail-text">ブルーライン/下永谷駅 歩28分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築35年</div>
# <div>4階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cassetteitem-item">
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox cassetteitem_other-checkbox--newarrival js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100320162483"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_6o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/483/100320162483/100320162483_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											3階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">8.3万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">8.3万円</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">8.3万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">3DK</span></li>
# <li><span class="cassetteitem_menseki">58m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100320162483">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000081009009/?bc=100320162483" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </li>
# <li>
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸アパート</span></div>
# <div class="cassetteitem_content-title">ファミリーコーポ笈川Ｂ</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">神奈川県横浜市戸塚区上倉田町</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ東海道本線/戸塚駅 歩11分</div>
# <div class="cassetteitem_detail-text">ブルーライン/舞岡駅 歩16分</div>
# <div class="cassetteitem_detail-text">ブルーライン/下永谷駅 歩28分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築36年</div>
# <div>2階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cassetteitem-item">
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100318616371"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_10o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/371/100318616371/100318616371_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">7.7万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">-</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">3DK</span></li>
# <li><span class="cassetteitem_menseki">49.68m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100318616371">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000063963752/?bc=100318616371" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </li>
# <li>
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸マンション</span></div>
# <div class="cassetteitem_content-title">コートパル戸塚</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">神奈川県横浜市戸塚区矢部町</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ東海道本線/戸塚駅 歩8分</div>
# <div class="cassetteitem_detail-text">ブルーライン/踊場駅 歩24分</div>
# <div class="cassetteitem_detail-text">相鉄いずみ野線/弥生台駅 バス21分 (バス停)矢部町 歩10分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築43年</div>
# <div>4階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cassetteitem-item">
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100272799061"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_9o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/061/100272799061/100272799061_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											3階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">8.2万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">4000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">16.4万円</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">-</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">3DK</span></li>
# <li><span class="cassetteitem_menseki">53.5m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# <li><span class="cassetteitem-tag">パノラマ</span></li>
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100272799061">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000072429930/?bc=100272799061" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </li>
# <li>
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸一戸建て</span></div>
# <div class="cassetteitem_content-title">戸塚町貸家</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">神奈川県横浜市戸塚区戸塚町</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ東海道本線/戸塚駅 歩9分</div>
# <div class="cassetteitem_detail-text">ブルーライン/踊場駅 歩20分</div>
# <div class="cassetteitem_detail-text">相鉄いずみ野線/弥生台駅 バス19分 (バス停)戸塚バスセンター 歩9分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築51年</div>
# <div>2階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cassetteitem-item">
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100287817018"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_s6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_11o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/018/100287817018/100287817018_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">7.5万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">-</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">7.5万円</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">7.5万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">3DK</span></li>
# <li><span class="cassetteitem_menseki">58.92m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# <li><span class="cassetteitem-tag">動画</span></li>
# <li><span class="cassetteitem-tag">パノラマ</span></li>
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100287817018">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000077862381/?bc=100287817018" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </li>
# </ul>
# <div class="l-inquiry">
# <div class="inquiry inquiry--middle">
# <div class="inquiry_item">
# <div class="inquiry_item-title"><span class="fr_list-eachicon fr_list-eachicon--check_inquiry inquiry_item-title-text"></span>チェックした物件を</div>
# <div class="inquiry_item-btn"><a class="ui-btn ui-btn--cta2 ui-btn--small listbtn--small js-allShiryoSeikyu" href="javascript:void(0);" onclick="sendBeaconSiteCatalystClick(event,this,'hankyo_list_button',self);return false;" title="問い合わせする">まとめて問い合わせする</a></div>
# </div>
# </div>
# </div>
# <ul class="l-cassetteitem">
# <li>
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# ...
# <div class="fixinquiry-action"><a class="fixinquiry_action js-allShiryoSeikyu" href="javascript:void(0);" onclick="sendBeaconSiteCatalystClick(event,this,'hankyo_bar',self);return false;" title="問い合わせする">まとめて問い合わせる<span class="fixinquiry_action-sub">(無料)</span></a></div>
# <div class="fixinquiry-attention">※同時に問い合わせできるのは<br>最大30件となります。</br></div>
# </div>
# </div>
# <!-- FrBukkenKensaku01 END -->
# <!-- GlobalFooter01_Suumo01 Start -->
# <div class="footer">
# <div class="footinfo">
# <div class="footinfo-inner">
# <p class="footinfo-txt">戸塚駅(神奈川県)付近や徒歩圏内でご希望の設備や間取りの賃借物件は見つかりましたか？エリアや駅など少し条件を変更して検索してみてはいかがでしょうか。あなたの理想の生活を叶える住居がきっと見つかります。戸塚駅(神奈川県)近辺の賃貸住宅(賃貸マンション、アパート、貸家)の住まい探しは情報豊富なSUUMO(スーモ)で！</p>
# <div class="footinfo-object"><span class="ui-icon--suumo06"></span></div>
# </div>
# </div>
# <!-- ↓===================================================================================================================↓ -->
# <!-- ↓/common/CM_040_030_FF_seo.html↓ -->
# <!-- ↑/common/CM_040_030_FF_seo.html↑ -->
# <!-- ↑===================================================================================================================↑ --><div class="footlinks">
# <div class="footlinks-inner">
# <!-- ↓===================================================================================================================↓ -->
# <!-- ↓/common/CM_000_030_FF_bar_gen.html↓ -->
# <div class="linkbox_group">
# <div class="linkbox linkbox--search">
# <div class="linkbox-body">
# <a class="js-setCookieArZenkoku" href="//suumo.jp/">全国の不動産情報へ</a>  |  <a href="//suumo.jp/kanto/">関東トップへ</a>
# </div>
# <div class="linkbox-search">
# <form action="/jj/common/ichiran/JJ901FC001/" id="js-wordSearch" method="post">
# <input name="ar" type="hidden" value="030"/>
# <input id="js-linkbox-search" name="kwd" placeholder="キーワード検索" type="text"/>
# <a class="ui-btn ui-btn--search ui-btn--small" href="javascript:void(0);" id="js-footerKensakuBtn">検索する</a>
# </form>
# </div>
# </div>
# </div>
# <!-- ↑/common/CM_000_030_FF_bar_gen.html↑ -->
# <!-- ↑===================================================================================================================↑ -->
# <!-- ↓===================================================================================================================↓ -->
# <!-- ↓/common/CM_000_000_FF_glo.html↓ -->
# <div class="linkbox_group">
# <div class="linkbox linkbox--full">
# <div class="linkbox-title">
# <a class="js-setCookieArZenkoku" href="//suumo.jp/">不動産・住宅サイト SUUMO（スーモ）</a>
# </div>
# <div class="linkbox-body">
# <a href="//suumo.jp/chintai/">賃貸</a>  |  <a href="//suumo.jp/chintai/mansion/">賃貸マンション</a>  |  <a href="//suumo.jp/chintai/apartment/">賃貸アパート</a>  |  <a href="//suumo.jp/chintai/nj_102/">賃貸一戸建て</a>  |  <a href="//suumo.jp/chintai/soba/">家賃相場</a>  |  <a href="//suumo.jp/ms/">マンション</a>  |  <a href="//suumo.jp/ms/shinchiku/">新築分譲マンション</a>  |  <a href="//suumo.jp/ms/chuko/">中古マンション</a>  |  <a href="//suumo.jp/ikkodate/">新築一戸建て</a>  |  <a href="//suumo.jp/chukoikkodate/">中古一戸建て</a>  |  <br><a href="//suumo.jp/tochi/">土地</a>  |  <a href="//suumo.jp/tokushu/renovation/">リノベーション物件</a>  |  <a href="//bessou.suumo.jp/" target="_blank">別荘・リゾート</a>  |  <a href="//inaka.suumo.jp/" target="_blank">移住・田舎暮らし</a>  |  <a href="//suumo.jp/chumon/">注文住宅</a>  |  <a href="//suumo.jp/remodel/">住宅リフォーム</a>  |  <a href="//suumo.jp/baikyaku/">不動産売却・査定</a>  |  <a href="https://www.suumocounter.jp/?vos=dsmcrecb20140123007" target="_blank">新築相談</a>  |  <a href="//hikkoshi.suumo.jp/" target="_blank">引越し見積もり</a>  |  <br><a href="//suumo.jp/loan/">住宅ローン</a>  |  <a href="//suumo.jp/library/" target="_blank">物件ライブラリー</a>  |  <a href="https://www.suumocounter.jp/fp/?suit=STct20170606005" target="_blank">ファイナンシャルプランナー無料相談</a>
# </br></br></div>
# </div>
# </div>
# <div class="linkbox_group">
# <div class="linkbox linkbox--full">
# <div class="linkbox-title">SUUMOエリアトップへ</div>
# <div class="linkbox-body">
# <a href="//suumo.jp/hokkaido/">北海道</a>  |  <a href="//suumo.jp/tohoku/">東北</a>  |  <a href="//suumo.jp/kanto/">関東</a>  |  <a href="//suumo.jp/koshinetsu/">甲信越・北陸</a>  |  <a href="//suumo.jp/tokai/">東海</a>  |  <a href="//suumo.jp/kansai/">関西</a>  |  <a href="//suumo.jp/shikoku/">四国</a>  |  <a href="//suumo.jp/chugoku/">中国</a>  |  <a href="//suumo.jp/kyushu/">九州・沖縄</a>
# </div>
# </div>
# </div>
# <!-- ↑/common/CM_000_000_FF_glo.html↑ -->
# <!-- ↑===================================================================================================================↑ -->
# </div>
# </div>
# <!-- ↓===================================================================================================================↓ -->
# <!-- ↓/common/CM_000_000_FF_logo.html↓ -->
# <div class="footlogo">
# <div class="logobox">
# <div>
# <a href="https://www.recruit.co.jp/" target="_blank"><img alt="リクルート" height="27" src="/edit/assets/suumo/img/include/inc_CM_all_000_crrecruit.gif" width="286"/></a>
# </div>
# </div>
# <div class="footlogo-link">
# <a href="//suumo.jp/edit/beginner/guide/">初めての方へ</a>  |  <a href="//suumo.jp/sitemap/">サイトマップ</a>  |  <a href="//cdn.p.recruit.co.jp/terms/suu-t-1003/index.html">利用規約</a>  |  <a href="//cdn.p.recruit.co.jp/terms/cmn-t-1001/index.html?p=pp005" target="_blank">プライバシーポリシー</a>  |  <a href="//suumo.jp/edit/sogotoiawase/" target="_blank">お問い合わせ</a>
# </div>
# <div class="footlogo-action">
# <a class="footlogo-action-btn" href="https://www.recruit.co.jp/employment/" target="_blank">採用情報</a>
# </div>
# </div>
# <!-- ↑/common/CM_000_000_FF_logo.html↑ -->
# <!-- ↑===================================================================================================================↑ --></div>
# <div id="js-pageTop">
# <a href="javascript:void(0);"><img alt="ページトップへ戻る" height="51" src="/edit/assets/suumo/img/pagetop.png" width="74"/></a>
# </div>
# <!-- latest_record_type:ICHIRAN -->
# <!-- "latest":{"ar":"030","bs":"040","ta":"","tf":"","sa":"","sc":"","oz":"","ra":"014","rn":"0160","ek":"016026210","cb":"0.0","ct":"10.0","co":"1","md":["09","10","11","12","13","14"],"ts":"","sd":"","kz":"","et":"15","mb":"45","mt":"9999999","cn":"9999999","tc":"","ekInput":"","tj":"","nk":"","po1":"","po2":"","page":"","pc":"","kc":"","kkc":"","tm":"","tmkbn":""} -->
# <!-- summary_record_type:FR_ICHIRAN -->
# <!-- "summary":{"ar":"030","bs":"040","orgurl2":"https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ra=014&cb=0.0&ct=10.0&co=1&et=15&md=09&md=10&md=11&md=12&md=13&md=14&cn=9999999&mb=45&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&","smk":"","tm":"","tmkbn":"","fb":["100320004332","100320162483","100318616371","100272799061","100287817018","100317982224","100308647458","100318868343","100305409497","100285784738","100131590323","100314047345","100317547407","100309726091","100318421206","100318479790","100283504475"],"kkc":[]} -->
# <!-- GlobalFooter01_Suumo01 End -->
# <div class="mylist_pop_wrap" id="js-mylistPop">
# <div class="mylist_pop dn">
# <p class="mylist_pop-txt"></p>
# </div>
# </div>
# <!-- JJ901FJ9111 START-->
# <form action="/jj/common/parts/JJ901FJ901/" id="js-premiumBannerForm" method="post">
# <input name="kkkKoseiCd" type="hidden" value="C900114">
# <input name="dc" type="hidden" value="1">
# </input></input></form>
# <div id="js-bannerPanel">
# <div id="bannerClose"></div>
# <div id="bannerTitle"></div>
# <div id="bannerWrapper">
# <div id="bannerContent"></div>
# </div>
# <div id="bannerFooter">Ads by SUUMO</div>
# </div>
# <!-- JJ901FJ9111 END -->
# <script src="/edit/assets/allsites/js/jquery-1.4.2.min.js?1501566650000"></script>
# <script src="/edit/assets/suumo/js/headerfooter.js?1655423532000"></script>
# <script src="/edit/assets/suumo/js/fr-list.js?1618545172000"></script>
# <script src="/edit/assets/suumo/js/include/inc-fr-list.js?1618453057000"></script>
# <script>
# 	/** クリップ登録：会員. */
# 	var CLIP_KAIIN = "11";
# 	/** クリップ登録：非会員. */
# 	var CLIP_HIKAIIN = "12";
# 	/** クリップ登録＋メール受信設定：会員. */
# 	var CLIP_AND_MAIL_KAIIN = "21";
# 	/** クリップ登録＋メール受信設定：非会員. */
# 	var CLIP_AND_MAIL_HIKAIIN = "22";
# 	/** メールアドレスチェック. */
# 	var CLIP_CHECK_MAIL = "90";
# 	/** 検索条件登録：会員. */
# 	var JOKEN_KAIIN = "11";
# 	/** 検索条件登録：非会員. */
# 	var JOKEN_HIKAIIN = "12";
# 	/** 検索条件登録＋メール受信設定：会員. */
# 	var JOKEN_AND_MAIL_KAIIN = "21";
# 	/** 検索条件登録＋メール受信設定：非会員. */
# 	var JOKEN_AND_MAIL_HIKAIIN = "22";
# 	/** メールアドレスチェック. */
# 	var JOKEN_CHECK_MAIL = "90";
# 	/** ログイン状態 */
#
# 	var login = false;
# </script>
# <script>
# /**
#  * controller
#  */
# $(function() {
# 	$('#js-leftColumnForm').submit(function() {
# 		return false;
# 	});
#
# 	// マイリストに追加するボタン
# 	$('#js-bukkenList .js-addMyList').click(function() {
# 		if ($(this).hasClass("is-inactive")) {
# 			suumo.frList.COMMON.deleteClipSingle(this);
# 		} else {
# 			suumo.frList.COMMON.registClipSingleForNayose(this);
# 		}
# 	});
# 	// 問い合わせする ボタン
# 	$('#js-bukkenList .js-singleShiryoSeikyu').click(function() {
# 		suumo.frList.COMMON.kobetsuShiryoSanPostAction(this.rel);
# 	});
# 	// このエリアの物件情報をもっと見る
# 	$('#js-singleLink').click(function() {
# 		suumo.frList.COMMON.openWindow('/jj/chintai/ichiran/FR301FC015/?'.unEscapeHTML(),'640','480','');
# 		return false;
# 	});
#
# 	// 賃貸プレミアムバナー
# 	$('#js-bannerPanel').suumoPremiumBanner({
# 		ajaxurl : $('#js-premiumBannerForm').attr('action'),
# 		ajaxdata : 'js-premiumBannerForm'
# 	});
#
# 		// 賃貸ローテーションバナー
#
# 		$('#js-fr_lotation_banner').load('/jj/common/parts/JJ901FJ901/?ar=030&ra=014&rn=0160&times=1678617361371&kkkKoseiCd=C900001&dc=4'.unEscapeHTML(), function () {
# 			if(!$('#js-fr_lotation_banner').html().match(/<span id="js-banner-none">/)) {
# 				$('#js-fr_lotation_banner').css('display', 'block');
# 			}
# 		});
# 		// 賃貸テキストバナー
# 		$('#js-fr_text_banner').load('/jj/common/parts/JJ901FJ901/?ar=030&ra=014&rn=0160&times=1678617361371&kkkKoseiCd=C900002&dc=1'.unEscapeHTML(), function () {
# 			if(!$('#js-fr_text_banner').html().match(/<span id="js-banner-none">/)) {
# 				$('#js-fr_text_banner').css('display', 'block');
# 			}
# 		});
#
#
#
# });
# </script>
# <!-- frKinesisPartsIchiran.jsp START -->
# <script type="text/javascript">
# //<![CDATA[
# 	var SuumoPageData = SuumoPageData || {};
# 	SuumoPageData.rtLog = SuumoPageData.rtLog || {};
# 	SuumoPageData.rtLog.action_type = 'TPV';
# 	SuumoPageData.rtLog.template_id = 'PC_SUUMO';
# 	SuumoPageData.rtLog.service_shubetsu_cd = '040';
# 	SuumoPageData.rtLog.ar = '030';
# 	SuumoPageData.rtLog.bs = '040';
#
# 	SuumoPageData.rtLog.cb = '0.0';
#
# 	SuumoPageData.rtLog.cn = '9999999';
#
# 	SuumoPageData.rtLog.co = ['1'];
#
# 	SuumoPageData.rtLog.ct = '10.0';
#
# 	SuumoPageData.rtLog.ek = ['016026210'];
#
# 	SuumoPageData.rtLog.et = '15';
#
# 	SuumoPageData.rtLog.mb = '45';
#
# 	SuumoPageData.rtLog.md = ['09','10','11','12','13','14'];
#
# 	SuumoPageData.rtLog.mt = '9999999';
#
# 	SuumoPageData.rtLog.pc = '30';
#
# 	SuumoPageData.rtLog.ra = '014';
#
# 	SuumoPageData.rtLog.rn = ['0160'];
#
# 	SuumoPageData.rtLog.shkr1 = '03';
#
# 	SuumoPageData.rtLog.shkr2 = '03';
#
# 	SuumoPageData.rtLog.shkr3 = '03';
#
# 	SuumoPageData.rtLog.shkr4 = '03';
#
# 	SuumoPageData.rtLog.bc = ['100320004332','100320162483','100318616371','100272799061','100287817018','100317982224','100308647458','100318868343','100305409497','100285784738','100131590323','100314047345','100317547407','100309726091','100318421206','100318479790','100283504475'];
#
# 	SuumoPageData.rtLog.server_id = 'web246suu';
#
# 	SuumoPageData.rtLog.request_id = '07N3C7K1025871';
#
#
# // ]]>
# </script>
# <!-- frKinesisPartsIchiran.jsp END -->
# <!-- ThirdPartyTagFrList01 START -->
# <!--Site Cayalyst Start -->
# <script language="JavaScript" src="/jj/jjcommon/sc/catalyst.js?20180328"></script>
# <script language="JavaScript"><!--
#
#
# var rsid = "FR";
# var tb = "040";
# //-->
# </script>
# <script language="JavaScript" src="/jj/jjcommon/sc/s_code.js"></script>
# <script language="JavaScript"><!--
# s.events = "";
# s.products = "";
# ke = "";
# bs = "";
# ss = "";
# bc = "";
# nc = "";
# tjh = "";
# jjh = "";
# kc = "";
# seq = "";
# s.pageName = "f301C01y";
# shiryoType = "";
# s.pageType = "";
# s.prop3 = "f301C01y";
# s.prop12 = "";
# s.prop13 = "C";
# s.prop14 = "040";
# s.prop15 = "030";
# s.prop16 = "";
# s.prop17 = "";
# s.prop18 = "";
# s.prop21 = "0";
# s.prop25 = "030";
# s.prop26 = addParam(s.prop26,"0160");
# s.prop26 = addParam(s.prop26,"014");
# s.prop27 = "";
# s.prop28 = addParam(s.prop28,"0.0");
# s.prop28 = addParam(s.prop28,"10.0");
# s.prop29 = addParam(s.prop29,"45");
# s.prop29 = addParam(s.prop29,"9999999");
# s.prop30 = ["09","10","11","12","13","14"];
# s.prop31 = "15";
# s.prop32 = getKskbn();
# s.prop33 = getSiteKbn();
# s.prop36 = "";
# s.prop37 = "";
# s.prop43 = "";
# s.prop55 = "";
# s.prop56 = "";
# s.eVar8 = "";
# s.eVar12 = "";
# s.eVar13 = "C";
# s.eVar14 = "040";
# s.eVar15 = "030";
# s.eVar16 = "";
# s.eVar17 = "";
# s.eVar18 = "";
# s.eVar19 = "";
# s.eVar21 = "0";
# s.eVar22 = "040";
# s.eVar25 = "030";
# s.eVar26 = addParam(s.eVar26,"0160");
# s.eVar26 = addParam(s.eVar26,"014");
# s.eVar27 = "";
# s.eVar28 = addParam(s.eVar28,"0.0");
# s.eVar28 = addParam(s.eVar28,"10.0");
# s.eVar29 = addParam(s.eVar29,"45");
# s.eVar29 = addParam(s.eVar29,"9999999");
# s.eVar30 = ["09","10","11","12","13","14"];
# s.eVar31 = "15";
# s.eVar32 = getKskbn();
# s.eVar33 = getSiteKbn();
# s.eVar36 = "";
# s.eVar37 = "";
# s.eVar40 = "";
# s.eVar55 = "";
# s.eVar56 = "";
# s.list1 = "";
# seikyuFlg = "";
# trace_p = "f301C01y";
#
# s.prop47 = "";
# s.eVar47 = "";
#
#
#
#
# var areaCd3 = getAreaCd(s.products, s.pageName);
# if(seikyuFlg == '2') {
# 	var shiryoId = getShiryoId(ss, bs);
# 	s.products = editShiryoParam( bc , nc , tjh , jjh , kc , seq , rsid , shiryoId , seikyuFlg , s.prop15, s.eVar22);
# } else if(seikyuFlg == '1') {
# 	var shiryoId = getShiryoId(ss, bs);
# 	var pageName = getPageName(shiryoId);
# 	s.products = editShiryoParam(  bc , nc , tjh , jjh , kc , seq , rsid , shiryoId , seikyuFlg , s.prop15, s.eVar22);
# 	s.pageName =  pageName;
# 	s.prop3 = pageName ;
# 	trace_p = pageName ;
# } else if(seikyuFlg == '3') {
# 	var shiryoId = '20';
# 	s.products = editShiryoParam( bc , nc , tjh , jjh , kc , seq , rsid , shiryoId , seikyuFlg , s.prop15, s.eVar22);
# } else {
# 	s.products = editProductsParam(s.products, rsid, s.eVar22, seikyuFlg);
# }
# s.prop12 = getKaisha(rsid , s.prop12);
# s.eVar12 = getKaisha(rsid , s.eVar12);
#
# trace_p = editVOSCode(s.eVar15, s.eVar25, areaCd3, s.eVar22, nc, bc, trace_p);
# s.pageName = getFrPageName(trace_p);
# s.prop3 = getFrPageName(trace_p);
# s.events = editEvents(s.eVar22, s.events);
#
# var s_code=s.t();if(s_code)document.write(s_code);//--></script>
# <!--Site Cayalyst End -->
# <form><input id="browserBack" style="display: none;" type="hidden"/></form>
# <!-- Visionalist Start -->
# <script src="/jj/jjcommon/vos/vos.js" type="text/javascript"></script>
# <!-- Visionalist End -->
# <!-- ThirdPartyTagFrList01 END -->
# <script type="text/javascript">
# 		//検索画面パネルに「この条件でマイリストに保存」チェックボックスのチェック状態をcookieに保存用名称
# 		var myListFlgName = 'mylistFlg';
# 		var cookieValue ='0';
# 		if (document.cookie && document.cookie != '') {
# 			var cookies = document.cookie.split(';');
# 			for (var i = 0; i < cookies.length; i++) {
# 				var cookie = jQuery.trim(cookies[i]);
# 				if (cookie.substring(0, myListFlgName.length + 1) == (myListFlgName + '=')) {
# 					cookieValue = decodeURIComponent(cookie.substring(myListFlgName.length + 1));
# 					break;
# 				}
# 			}
# 		}
# 		//検索画面パネルに「この条件でマイリストに保存」チェックとなっていた場合
# 	    if(cookieValue == '1'){
# 			//検索条件保存機能を呼び出す
# 			suumo.frList.COMMON.registKensakuJoken(login);
# 			//cookeiにチェックボックスのチェック状態の値を削除
# 			document.cookie="mylistFlg=0;path=/;";
# 		}
# 	</script>
# <script type="text/javascript">
# 		var _WkWkParams = _WkWkParams || [];
# 		_WkWkParams.push(['NO_TPV']);
# 	</script>
# <script src="https://log.suumo.jp/js/logsuumo.js"></script>
# <!-- SendBeacon start -->
# <!-- SendBeacon end -->
# <script src="/jj/jjcommon/js/send-beacon.js?1540520180000"></script>
# <script src="/jj/jjcommon/chintai/js/onloadCallTeBeacon.js?1540519949000"></script>
# <script type="text/javascript">
# 		function sendBeaconSiteCatalystClick(event, obj, clickLabel, self) {
# 			if(clickLabel=='click_casset_bkn_link'){
# 				  s.linkTrackVars = 'prop1,prop2,prop3,prop58,eVar40';
# 			}else{
# 				s.linkTrackVars = 'prop1,prop2,prop3,prop58';
# 			}
# 			s.prop58 = clickLabel;
# 			if (self) {
# 				s.tl(obj, 'o', clickLabel, null, 'navigate');
# 			} else {
# 				s.tl(obj, 'o', clickLabel);
# 			}
# 			WkWkTracker.trackEvent(event, [ [ 'eventName', clickLabel ] ]);
# 		};
# 	</script>
# </body>
# <!-- FR301FC0012 END -->
# </html>

# %%
import datetime as dt
format(dt.datetime.today(),'%Y/%m/%d')
# Out:
# '2023/03/12'

# %%
elem.find('img', class_='js-linkImage')[]
# Out:
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/332/100320004332/100320004332_gw.jpg" src="...%3D%3D" width="0">
# </img>
